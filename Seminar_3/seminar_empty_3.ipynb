# %%
import requests
import pandas as pd
import time

# %% [markdown]
# # Seminar - APIs, DBs and Live coding

# %% [markdown]
# ## Task 1: Requesting API
# ### 1a. Create a function requesting data from sreality
#
#
# ```python
# base_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb=1&category_type_cb=1&locality_region_id=10&per_page60&page={}'.format(i)
#
# r = requests.get(base_url)
# d = r.json()
# ```
#
# * function should parametrize:
#     * `category_main_cb` - `{'flat':1, 'house':2, 'land':3 }`
#     * `category_type_cb` - `{'sell':1,'rent':2}`
#     * `locality_region_id` - use 10 as default value
#     * `page` parameter
# * use string inputs for `category_main_cb` and `category_type_cb`
# * include try/except clause to handle errors
# * function should return JSON data in python types
# * do not forget to sleep each request at least 0.5s

# %%
def request_sreality(page, category_main_str, category_type_str, locality_region_id=10):
    category_mains = {'flat':1, 'house':2, 'land':3 }
    category_types = {'sell':1,'rent':2}
    template_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb={category_main}&category_type_cb={category_type}&locality_region_id={locality_region_id}&per_page60&page={page}'
    try:
        request_url = template_url.format(
            category_main=category_mains[category_main_str],
            category_type=category_types[category_type_str],
            locality_region_id=locality_region_id,
            page=page
        )
        r = requests.get(request_url)
        return r.json()
    except Exception as e:
        print(e)
        
d = request_sreality(0, 'flat', 'sell', 10)

# %%
d
# Out:
# {'meta_description': '4483 realit v nabídce prodej bytů Praha. Vyberte si novou nemovitost na sreality.cz s hledáním na mapě a velkými náhledy fotografií nabízených bytů.',
#  'result_size': 4483,
#  '_embedded': {'estates': [{'labelsReleased': [['panel', 'partly_furnished'],
#      []],
#     'has_panorama': 0,
#     'labels': ['Panelová', 'Částečně vybavený'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'panel',
#       'cellar',
#       'elevator',
#       'partly_furnished'],
#      ['tavern',
#       'restaurant',
#       'kindergarten',
#       'small_shop',
#       'vet',
#       'sports',
#       'medic',
#       'drugstore',
#       'school',
#       'candy_shop',
#       'theater',
#       'atm',
#       'shop',
#       'post_office',
#       'movies',
#       'bus_public_transport',
#       'playground',
#       'tram',
#       'metro',
#       'train']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 5,
#      'category_type_cb': 1,
#      'locality': 'praha-cimice-chvaterubska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1371391308',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1371391308',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Grygar-reality-Praha-Vinohrady',
#       'id': 34012,
#       'name': 'Grygar reality',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gS_l/NIOZoC.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 8 - Čimice',
#     'has_video': False,
#     'advert_images_count': 30,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1371391308,
#     'attractive_offer': 0,
#     'price': 2919000,
#     'price_czk': {'value_raw': 2919000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/09Sa1k.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/09Sa1k.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-20?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1371391308?region_tip=2823077'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/09Sa1k.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/OmAzxz.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MN/4sIz3z.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/jJczx0.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/Nl6zx1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/7lWmT0.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/09Sa1k.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+1\xa029\xa0m²',
#     'region_tip': 2823077,
#     'gps': {'lat': 50.129854623362974, 'lon': 14.439219376637029},
#     'has_matterport_url': False},
#    {'labelsReleased': [['furnished'], []],
#     'has_panorama': 0,
#     'labels': ['Vybavený'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick', 'cellar', 'elevator', 'furnished'],
#      ['tavern',
#       'candy_shop',
#       'small_shop',
#       'theater',
#       'vet',
#       'movies',
#       'playground',
#       'sightseeing',
#       'atm',
#       'bus_public_transport',
#       'drugstore',
#       'metro',
#       'restaurant',
#       'train',
#       'tram',
#       'school',
#       'post_office',
#       'medic',
#       'kindergarten',
#       'shop',
#       'sports']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-nove-mesto-skolska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3079939148',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3079939148',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 1 - Nové Město',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 3079939148,
#     'attractive_offer': 0,
#     'price': 5526000,
#     'price_czk': {'value_raw': 5526000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J3/ef6KoV.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J3/ef6KoV.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-19?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/3079939148'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J3/ef6KoV.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jl/8w4Knv.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Ky/49XKsK.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J2/I4FKqS.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ld/vMDKqP.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J2/8v1KqT.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J3/ef6KoV.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 30\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.073278623362974, 'lon': 14.43000437663703},
#     'has_matterport_url': False},
#    {'labelsReleased': [['after_reconstruction'], []],
#     'has_panorama': 0,
#     'labels': ['Po rekonstrukci'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'after_reconstruction',
#       'brick',
#       'cellar',
#       'elevator',
#       'not_furnished'],
#      ['candy_shop',
#       'theater',
#       'small_shop',
#       'vet',
#       'tavern',
#       'movies',
#       'playground',
#       'natural_attraction',
#       'sightseeing',
#       'tram',
#       'atm',
#       'kindergarten',
#       'sports',
#       'metro',
#       'train',
#       'bus_public_transport',
#       'post_office',
#       'drugstore',
#       'medic',
#       'shop',
#       'school',
#       'restaurant']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-nove-mesto-reznicka'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1289888844',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1289888844',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 1 - Nové Město',
#     'has_video': False,
#     'advert_images_count': 22,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1289888844,
#     'attractive_offer': 0,
#     'price': 7229000,
#     'price_czk': {'value_raw': 7229000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ld/dwQB4F.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ld/dwQB4F.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-18?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1289888844'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ld/dwQB4F.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jm/iGBd43.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_La/SrIP31.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MB/ztnB5Z.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MJ/Lsoyu1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jh/MNkPve.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ld/dwQB4F.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 38\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.07246262336297, 'lon': 14.43000237663703},
#     'has_matterport_url': False},
#    {'labelsReleased': [['in_construction', 'collective', 'balcony'], []],
#     'has_panorama': 0,
#     'labels': ['Ve výstavbě', 'Družstevní', 'Balkon'],
#     'is_auction': False,
#     'labelsAll': [['in_construction',
#       'collective',
#       'balcony',
#       'brick',
#       'not_furnished'],
#      ['small_shop',
#       'tavern',
#       'candy_shop',
#       'vet',
#       'playground',
#       'theater',
#       'natural_attraction',
#       'movies',
#       'bus_public_transport',
#       'drugstore',
#       'metro',
#       'school',
#       'shop',
#       'kindergarten',
#       'post_office',
#       'medic',
#       'atm',
#       'tram',
#       'train',
#       'sports',
#       'restaurant']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-praha-9-nad-krocinkou'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/290006348',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/290006348',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'RE-MAX-Partner-Praha-Reporyje',
#       'id': 17196,
#       'name': 'RE/MAX Partner',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QN_3/rSiLCT.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 9',
#     'has_video': False,
#     'advert_images_count': 6,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 290006348,
#     'attractive_offer': 0,
#     'price': 0,
#     'price_czk': {'value_raw': 0, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/4aVmLG.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/4aVmLG.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-17?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/290006348'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/4aVmLG.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/AcLmLH.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/JGonjb.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/H73mLJ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/Lhjzk2.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/RFiz0P.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/4aVmLG.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 29\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.11171162336297, 'lon': 14.491121376637029},
#     'has_matterport_url': False},
#    {'labelsReleased': [['terrace', 'partly_furnished'], []],
#     'has_panorama': 0,
#     'labels': ['Terasa', 'Částečně vybavený'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'terrace',
#       'brick',
#       'elevator',
#       'partly_furnished'],
#      ['tavern',
#       'candy_shop',
#       'small_shop',
#       'theater',
#       'vet',
#       'movies',
#       'playground',
#       'sightseeing',
#       'metro',
#       'restaurant',
#       'school',
#       'shop',
#       'atm',
#       'train',
#       'medic',
#       'sports',
#       'kindergarten',
#       'drugstore',
#       'bus_public_transport',
#       'tram',
#       'post_office']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 5,
#      'category_type_cb': 1,
#      'locality': 'praha-nove-mesto-skolska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2725778764',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2725778764',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 1 - Nové Město',
#     'has_video': False,
#     'advert_images_count': 19,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2725778764,
#     'attractive_offer': 0,
#     'price': 7536000,
#     'price_czk': {'value_raw': 7536000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/eVkXux.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/eVkXux.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-16?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2725778764'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/eVkXux.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/L9ULol.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/CB6KSd.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ls/06XXyG.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/uNOX4X.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/M0bXuv.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/eVkXux.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+1\xa032\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.073278623362974, 'lon': 14.43000437663703},
#     'has_matterport_url': False},
#    {'labelsReleased': [['partly_furnished'], ['train', 'post_office']],
#     'has_panorama': 0,
#     'labels': ['Částečně vybavený', 'Vlak 6 min. pěšky', 'Pošta 6 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick', 'partly_furnished'],
#      ['small_shop',
#       'candy_shop',
#       'theater',
#       'tavern',
#       'vet',
#       'movies',
#       'playground',
#       'sightseeing',
#       'restaurant',
#       'post_office',
#       'metro',
#       'school',
#       'atm',
#       'drugstore',
#       'tram',
#       'kindergarten',
#       'medic',
#       'train',
#       'shop',
#       'sports',
#       'bus_public_transport']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-nusle-mecislavova'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3052594508',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3052594508',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 4 - Nusle',
#     'has_video': True,
#     'advert_images_count': 18,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 3052594508,
#     'attractive_offer': 0,
#     'price': 3181000,
#     'price_czk': {'value_raw': 3181000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_z/HYQDTS.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_z/HYQDTS.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-15?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/3052594508'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_z/HYQDTS.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/TadDTN.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gT_3/qF5DR3.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_z/OytDS2.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/Mj3HfF.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MN/LeMHd0.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_z/HYQDTS.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 28\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.05916462336297, 'lon': 14.44985137663703},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], ['post_office']],
#     'has_panorama': 0,
#     'labels': ['Pošta 2 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['new_building', 'personal'],
#      ['small_shop',
#       'tavern',
#       'movies',
#       'candy_shop',
#       'theater',
#       'vet',
#       'playground',
#       'natural_attraction',
#       'metro',
#       'drugstore',
#       'post_office',
#       'kindergarten',
#       'sports',
#       'tram',
#       'shop',
#       'medic',
#       'restaurant',
#       'train',
#       'atm',
#       'school',
#       'bus_public_transport']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-stodulky-habova'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3075359820',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3075359820',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Trigema-a-s-Praha-Stodulky',
#       'id': 2995,
#       'name': 'Trigema a.s.',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gW_f/UoZMGF.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5 - Stodůlky',
#     'has_video': False,
#     'advert_images_count': 12,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 3075359820,
#     'attractive_offer': 0,
#     'price': 4119000,
#     'price_czk': {'value_raw': 4119000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jt/vCKZaF.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jt/vCKZaF.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-14?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/3075359820'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jt/vCKZaF.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Ju/FRGZHM.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_K8/pc5ZJX.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_ML/xcFZNa.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jo/RdDZI6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KE/G4JZKr.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jt/vCKZaF.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 24\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.04077762336297, 'lon': 14.31613837663703},
#     'has_matterport_url': False},
#    {'labelsReleased': [['balcony', 'parking_lots'], []],
#     'has_panorama': 0,
#     'labels': ['Balkon', 'Parkování'],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'balcony',
#       'cellar',
#       'elevator',
#       'parking_lots'],
#      ['small_shop',
#       'vet',
#       'candy_shop',
#       'tavern',
#       'theater',
#       'playground',
#       'movies',
#       'shop',
#       'school',
#       'sports',
#       'tram',
#       'drugstore',
#       'kindergarten',
#       'medic',
#       'bus_public_transport',
#       'train',
#       'atm',
#       'post_office',
#       'restaurant',
#       'metro']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-praha-cakovice-belomlynska'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/547366220',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/547366220',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Sekyra-Group-a-s-Praha-Karlin',
#       'id': 3360,
#       'name': 'Sekyra Group, a.s.',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QI_g/RYpNU.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 9 - Praha-Čakovice',
#     'has_video': False,
#     'advert_images_count': 5,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 547366220,
#     'attractive_offer': 0,
#     'price': 3571000,
#     'price_czk': {'value_raw': 3571000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/AxeSgT.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/AxeSgT.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-13?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/547366220'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/AxeSgT.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/j8rSbP.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/tjWhO6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_z/aV0SjU.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_z/svoSjV.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/AxeSgT.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 29\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.15230462336297, 'lon': 14.53236737663703},
#     'has_matterport_url': False},
#    {'labelsReleased': [['collective'], []],
#     'has_panorama': 0,
#     'labels': ['Družstevní'],
#     'is_auction': False,
#     'labelsAll': [['collective', 'brick', 'cellar', 'elevator'],
#      ['small_shop',
#       'candy_shop',
#       'vet',
#       'theater',
#       'tavern',
#       'movies',
#       'playground',
#       'natural_attraction',
#       'sightseeing',
#       'atm',
#       'metro',
#       'post_office',
#       'kindergarten',
#       'drugstore',
#       'shop',
#       'school',
#       'medic',
#       'sports',
#       'bus_public_transport',
#       'tram',
#       'train',
#       'restaurant']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-vinohrady-hradecka'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1694820172',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1694820172',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Duna-House-Praha-Michle',
#       'id': 43314,
#       'name': 'Duna House',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QJ_g/AKtCu.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 3 - Vinohrady',
#     'has_video': False,
#     'advert_images_count': 10,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1694820172,
#     'attractive_offer': 0,
#     'price': 6135000,
#     'price_czk': {'value_raw': 6135000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/9rlzlp.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/9rlzlp.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-12?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1694820172'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/9rlzlp.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jx/sOeYeZ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/wjLzlq.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/ddPmJD.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/spzng5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/d2jziB.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/9rlzlp.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 36\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.07100862336297, 'lon': 14.46946937663703},
#     'has_matterport_url': False},
#    {'labelsReleased': [['loggia', 'panel'], ['train']],
#     'has_panorama': 0,
#     'labels': ['Lodžie', 'Panelová', 'Vlak 5 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'loggia', 'panel', 'cellar', 'elevator'],
#      ['small_shop',
#       'vet',
#       'tavern',
#       'candy_shop',
#       'theater',
#       'playground',
#       'natural_attraction',
#       'movies',
#       'shop',
#       'train',
#       'restaurant',
#       'atm',
#       'drugstore',
#       'bus_public_transport',
#       'tram',
#       'sports',
#       'medic',
#       'post_office',
#       'metro',
#       'kindergarten',
#       'school']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 7,
#      'category_type_cb': 1,
#      'locality': 'praha-repy-vondrousova'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/566302028',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/566302028',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 6 - Řepy',
#     'has_video': False,
#     'advert_images_count': 19,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 566302028,
#     'attractive_offer': 0,
#     'price': 3851000,
#     'price_czk': {'value_raw': 3851000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/i71Y8O.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/i71Y8O.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-11?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/566302028'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/i71Y8O.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_z/RlMZAE.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/IXQhXg.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/9Wbta1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_0/BqhZDy.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/gLXY2Q.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/i71Y8O.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+1\xa045\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.05858462336297, 'lon': 14.30650237663703},
#     'has_matterport_url': False},
#    {'labelsReleased': [['partly_furnished'], ['post_office']],
#     'has_panorama': 0,
#     'labels': ['Částečně vybavený', 'Pošta 1 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick', 'cellar', 'partly_furnished'],
#      ['candy_shop',
#       'small_shop',
#       'theater',
#       'tavern',
#       'vet',
#       'movies',
#       'playground',
#       'natural_attraction',
#       'sightseeing',
#       'sports',
#       'metro',
#       'medic',
#       'bus_public_transport',
#       'school',
#       'tram',
#       'drugstore',
#       'restaurant',
#       'shop',
#       'post_office',
#       'kindergarten',
#       'train',
#       'atm']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 7,
#      'category_type_cb': 1,
#      'locality': 'praha-smichov-ostrovskeho'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3828229452',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3828229452',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Realitni-expert-Ing-Lucie-Mekhail-Lany',
#       'id': 43446,
#       'name': 'Realitní expert Ing. Lucie Mekhail',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gW_g/FIgBLy.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5 - Smíchov',
#     'has_video': False,
#     'advert_images_count': 15,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 3828229452,
#     'attractive_offer': 0,
#     'price': 6363000,
#     'price_czk': {'value_raw': 6363000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/noLBIu.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/noLBIu.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-10?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/3828229452'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/noLBIu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/H2GBIU.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ls/HiSCJE.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/l0EBIv.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LM/0FbCIi.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_z/RoeBJc.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/noLBIu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+1\xa049\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.06300162336297, 'lon': 14.40556537663703},
#     'has_matterport_url': False},
#    {'labelsReleased': [['after_reconstruction', 'furnished'], ['shop']],
#     'has_panorama': 0,
#     'labels': ['Po rekonstrukci', 'Vybavený', 'Obchod 5 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'after_reconstruction',
#       'brick',
#       'elevator',
#       'furnished'],
#      ['tavern',
#       'candy_shop',
#       'theater',
#       'small_shop',
#       'vet',
#       'movies',
#       'playground',
#       'natural_attraction',
#       'sightseeing',
#       'restaurant',
#       'medic',
#       'kindergarten',
#       'metro',
#       'post_office',
#       'bus_public_transport',
#       'shop',
#       'school',
#       'train',
#       'drugstore',
#       'tram',
#       'atm',
#       'sports']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 7,
#      'category_type_cb': 1,
#      'locality': 'praha-stare-mesto-'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/4188198220',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/4188198220',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'REFA-Group-s-r-o-Praha-Zizkov',
#       'id': 15138,
#       'name': 'REFA Group s.r.o.',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gT_u/9gnCrW.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 1 - Staré Město',
#     'has_video': False,
#     'advert_images_count': 13,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 4188198220,
#     'attractive_offer': 0,
#     'price': 11103000,
#     'price_czk': {'value_raw': 11103000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/34BB129.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/34BB129.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-9?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/4188198220'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/34BB129.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LH/Wb4B1mK.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jt/gNPB1uF.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/VnxB13A.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_K7/k5YB1sk.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_K7/FFCB1sl.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/34BB129.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+1\xa049\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.07889362336297, 'lon': 14.42329237663703},
#     'has_matterport_url': False},
#    {'labelsReleased': [['balcony', 'partly_furnished'], []],
#     'has_panorama': 0,
#     'labels': ['Balkon', 'Částečně vybavený'],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'balcony',
#       'brick',
#       'elevator',
#       'garage',
#       'partly_furnished'],
#      ['small_shop',
#       'tavern',
#       'candy_shop',
#       'vet',
#       'movies',
#       'theater',
#       'playground',
#       'natural_attraction',
#       'metro',
#       'medic',
#       'tram',
#       'shop',
#       'bus_public_transport',
#       'sports',
#       'atm',
#       'post_office',
#       'train',
#       'school',
#       'kindergarten',
#       'drugstore',
#       'restaurant']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-hostivar-rychtare-petrika'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1581876556',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1581876556',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'GEPARD-REALITY-Pallas-Athena-Praha-Karlin',
#       'id': 27595,
#       'name': 'GEPARD REALITY/Pallas Athena',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gS_q/LZWGxb.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 10 - Hostivař',
#     'has_video': True,
#     'advert_images_count': 20,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1581876556,
#     'attractive_offer': 0,
#     'price': 3740000,
#     'price_czk': {'value_raw': 3740000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/2VbYCa.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/2VbYCa.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-8?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1581876556'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/2VbYCa.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jn/BVSX2J.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Lp/aJhYHc.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J9/90KX6J.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J9/GerX6K.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Js/8L3YCu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/2VbYCa.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 25\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.05015062336297, 'lon': 14.53087937663703},
#     'has_matterport_url': False},
#    {'labelsReleased': [['balcony'], []],
#     'has_panorama': 0,
#     'labels': ['Balkon'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'balcony', 'brick', 'cellar'],
#      ['small_shop',
#       'vet',
#       'candy_shop',
#       'theater',
#       'tavern',
#       'movies',
#       'playground',
#       'sightseeing',
#       'atm',
#       'metro',
#       'drugstore',
#       'sports',
#       'shop',
#       'restaurant',
#       'bus_public_transport',
#       'kindergarten',
#       'medic',
#       'post_office',
#       'train',
#       'tram',
#       'school']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-nusle-zateckych'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1206252876',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1206252876',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 4 - Nusle',
#     'has_video': False,
#     'advert_images_count': 30,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1206252876,
#     'attractive_offer': 0,
#     'price': 5520000,
#     'price_czk': {'value_raw': 5520000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/MMqz0r.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/MMqz0r.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-7?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1206252876'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/MMqz0r.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/kyGatG.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/Z5enj5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/xRFHNM.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_0/CcVHPW.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/zk6nj4.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/MMqz0r.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 41\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.05491462336297, 'lon': 14.43956137663703},
#     'has_matterport_url': False},
#    {'labelsReleased': [['balcony'], []],
#     'has_panorama': 0,
#     'labels': ['Balkon'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'balcony',
#       'elevator',
#       'garage',
#       'not_furnished'],
#      ['small_shop',
#       'theater',
#       'candy_shop',
#       'vet',
#       'tavern',
#       'movies',
#       'sightseeing',
#       'playground',
#       'shop',
#       'medic',
#       'bus_public_transport',
#       'tram',
#       'sports',
#       'atm',
#       'post_office',
#       'metro',
#       'drugstore',
#       'school',
#       'train',
#       'restaurant',
#       'kindergarten']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-holesovice-jatecni'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/4054193484',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/4054193484',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'CREDITAS-Real-Estate-Praha-Jinonice',
#       'id': 27848,
#       'name': 'CREDITAS Real Estate',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_s/whOD0n.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 7 - Holešovice',
#     'has_video': False,
#     'advert_images_count': 7,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 4054193484,
#     'attractive_offer': 0,
#     'price': 4962000,
#     'price_czk': {'value_raw': 4962000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/HrrYmi.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/HrrYmi.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-6?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/4054193484'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/HrrYmi.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/T0zYrT.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/fzlT1c.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ls/fPDszf.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/E2fYrU.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_z/TqiYxW.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/HrrYmi.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 26\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.09511062336297, 'lon': 14.45431837663703},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['personal', 'elevator', 'garage', 'not_furnished'],
#      ['small_shop',
#       'theater',
#       'vet',
#       'candy_shop',
#       'tavern',
#       'movies',
#       'sightseeing',
#       'playground',
#       'restaurant',
#       'school',
#       'metro',
#       'drugstore',
#       'train',
#       'tram',
#       'kindergarten',
#       'atm',
#       'bus_public_transport',
#       'sports',
#       'medic',
#       'post_office',
#       'shop']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 2,
#      'category_type_cb': 1,
#      'locality': 'praha-holesovice-jatecni'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2544244044',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2544244044',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'CREDITAS-Real-Estate-Praha-Jinonice',
#       'id': 27848,
#       'name': 'CREDITAS Real Estate',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_s/whOD0n.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 7 - Holešovice',
#     'has_video': False,
#     'advert_images_count': 7,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2544244044,
# ...
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/1estA3.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/vYJsug.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/mDRYsx.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/Hkisuf.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 37\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.09511062336297, 'lon': 14.45431837663703},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'brick',
#       'elevator',
#       'garage',
#       'not_furnished'],
#      ['candy_shop',
#       'tavern',
#       'small_shop',
#       'theater',
#       'movies',
#       'vet',
#       'playground',
#       'natural_attraction',
#       'sightseeing',
#       'tram',
#       'atm',
#       'bus_public_transport',
#       'shop',
#       'drugstore',
#       'metro',
#       'train',
#       'school',
#       'sports',
#       'medic',
#       'kindergarten',
#       'restaurant',
#       'post_office']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-jinonice-reporyjska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/487134540',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/487134540',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'CREDITAS-Real-Estate-Praha-Jinonice',
#       'id': 27848,
#       'name': 'CREDITAS Real Estate',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_s/whOD0n.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5 - Jinonice',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 487134540,
#     'attractive_offer': 0,
#     'price': 6567000,
#     'price_czk': {'value_raw': 6567000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jq/IpxWTn.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jq/IpxWTn.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-3?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/487134540'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jq/IpxWTn.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/d59WXc.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/J9hMv6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/WdLMsH.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/n29I8B.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/JkfWbh.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jq/IpxWTn.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 48\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.04587062336297, 'lon': 14.36083637663703},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'brick',
#       'garage',
#       'not_furnished'],
#      ['candy_shop',
#       'tavern',
#       'small_shop',
#       'theater',
#       'movies',
#       'playground',
#       'vet',
#       'natural_attraction',
#       'sightseeing',
#       'post_office',
#       'sports',
#       'atm',
#       'train',
#       'shop',
#       'medic',
#       'tram',
#       'restaurant',
#       'bus_public_transport',
#       'drugstore',
#       'school',
#       'kindergarten',
#       'metro']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-jinonice-reporyjska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1379472716',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1379472716',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'CREDITAS-Real-Estate-Praha-Jinonice',
#       'id': 27848,
#       'name': 'CREDITAS Real Estate',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_s/whOD0n.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5 - Jinonice',
#     'has_video': False,
#     'advert_images_count': 14,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1379472716,
#     'attractive_offer': 0,
#     'price': 8084000,
#     'price_czk': {'value_raw': 8084000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/14mKRt.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/14mKRt.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-2?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1379472716'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/14mKRt.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jq/kKBWN9.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/uftMsC.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gQ_0/PQnMnK.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/u6fKRu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jw/wMBWQ6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/14mKRt.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 60\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.04587062336297, 'lon': 14.36083637663703},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'brick',
#       'garage',
#       'not_furnished'],
#      ['candy_shop',
#       'tavern',
#       'small_shop',
#       'theater',
#       'movies',
#       'playground',
#       'vet',
#       'natural_attraction',
#       'sightseeing',
#       'drugstore',
#       'shop',
#       'sports',
#       'atm',
#       'school',
#       'kindergarten',
#       'medic',
#       'train',
#       'bus_public_transport',
#       'tram',
#       'restaurant',
#       'metro',
#       'post_office']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-jinonice-reporyjska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2604209484',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2604209484',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'CREDITAS-Real-Estate-Praha-Jinonice',
#       'id': 27848,
#       'name': 'CREDITAS Real Estate',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_s/whOD0n.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5 - Jinonice',
#     'has_video': False,
#     'advert_images_count': 13,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2604209484,
#     'attractive_offer': 0,
#     'price': 5051000,
#     'price_czk': {'value_raw': 5051000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/C1BI3h.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/C1BI3h.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-1?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2604209484'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/C1BI3h.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/32qWeZ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_0/8GNMsy.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_z/eXAMwq.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/o4eWdL.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/e5wWW9.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/C1BI3h.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 36\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.04587062336297, 'lon': 14.36083637663703},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'brick',
#       'garage',
#       'not_furnished'],
#      ['candy_shop',
#       'tavern',
#       'small_shop',
#       'theater',
#       'movies',
#       'vet',
#       'playground',
#       'natural_attraction',
#       'sightseeing',
#       'train',
#       'medic',
#       'school',
#       'post_office',
#       'sports',
#       'tram',
#       'drugstore',
#       'kindergarten',
#       'shop',
#       'bus_public_transport',
#       'metro',
#       'restaurant',
#       'atm']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-jinonice-reporyjska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2704872780',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2704872780',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'CREDITAS-Real-Estate-Praha-Jinonice',
#       'id': 27848,
#       'name': 'CREDITAS Real Estate',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_s/whOD0n.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5 - Jinonice',
#     'has_video': False,
#     'advert_images_count': 15,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2704872780,
#     'attractive_offer': 0,
#     'price': 7326000,
#     'price_czk': {'value_raw': 7326000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/FTOI2A.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/FTOI2A.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/0?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2704872780'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/FTOI2A.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_z/0WGMxe.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gQ_0/W18Mmq.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/RhhWbd.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/JlPWVX.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/DM0MsM.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/FTOI2A.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 51\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.04587062336297, 'lon': 14.36083637663703},
#     'has_matterport_url': False}],
#   'is_saved': {'email_notification': False,
#    'notification_advert_count': 0,
#    'stack_id': 0,
#    'push_notification': False,
#    '_links': {'self': {'href': '/cs/v2/stacks'}},
#    'removed': False,
#    'saved': False},
#   'not_precise_location_count': {'result_size_auction': 0,
#    'result_size': 1162,
#    '_links': {'self': {'profile': '/estates/count/doc',
#      'href': '/cs/v2/estates/count?category_main_cb=1&locality_region_id=10&category_type_cb=3',
#      'title': 'Estate count'}}}},
#  'filterLabels': [],
#  'title': 'Byty na prodej Praha',
#  'filter': {'category_main_cb': '1',
#   'suggested_districtId': -1,
#   'locality_region_id': '10',
#   'category_type_cb': '1',
#   'suggested_regionId': -1},
#  '_links': {'self': {'href': '/cs/v2/estates?category_main_cb=1&locality_region_id=10&category_type_cb=1&page=0'},
#   'clusters_with_bounding_box_of_first_10': {'href': '/cs/v2/clusters?category_main_cb=1&locality_region_id=10&category_type_cb=1&per_page60=&leftBottomBounding=14.3065023766|50.0407776234&page=0&rightTopBounding=14.5323673766|50.1523046234'},
#   'rss': {'href': '/api/cs/v2/estates/rss?category_main_cb=1&category_type_cb=1&locality_region_id=10&suggested_regionId=-1&suggested_districtId=-1'}},
#  'locality': 'okres Praha 1',
#  'locality_dativ': 'na Praze 1',
#  'logged_in': False,
#  'per_page': 20,
#  'category_instrumental': 'výběrem či prodejem bytu',
#  'page': 0,
#  'filterLabels2': {'something_more3_3310': 'elevator',
#   'something_more1_3120': 'cellar',
#   'something_more1_3100': 'loggia',
#   'furnished_1': 'furnished',
#   'furnished_2': 'partly_furnished',
#   'furnished_3': 'not_furnished',
#   'building_condition_9': 'after_reconstruction',
#   'something_more2_3150': 'garage',
#   'something_more2_3130': 'basin',
#   'ownership_1': 'personal',
#   'ownership_3': 'state',
#   'ownership_2': 'collective',
#   'something_more3_1820': 'easy_access',
#   'energy_efficiency_rating_search_7': 'energy_rating_g',
#   'energy_efficiency_rating_search_6': 'energy_rating_f',
#   'energy_efficiency_rating_search_5': 'energy_rating_e',
#   'energy_efficiency_rating_search_4': 'energy_rating_d',
#   'energy_efficiency_rating_search_3': 'energy_rating_c',
#   'energy_efficiency_rating_search_2': 'energy_rating_b',
#   'energy_efficiency_rating_search_1': 'energy_rating_a',
#   'something_more1_3110': 'terrace',
#   'building_condition_6': 'new_building',
#   'something_more1_3090': 'balcony',
#   'building_condition_4': 'in_construction',
#   'building_type_search_3': 'other_sigular',
#   'something_more2_3120': 'cellar',
#   'building_type_search_1': 'panel',
#   'something_more2_3140': 'parking_lots',
#   'something_more1_200222': 'garden',
#   'building_type_search_2': 'brick'}}

# %%
d.keys()
# Out:
# dict_keys(['meta_description', 'result_size', '_embedded', 'filterLabels', 'title', 'filter', '_links', 'locality', 'locality_dativ', 'logged_in', 'per_page', 'category_instrumental', 'page', 'filterLabels2'])

# %%
d['_embedded'].keys()
# Out:
# dict_keys(['estates', 'is_saved', 'not_precise_location_count'])

# %%
d['_embedded']['estates']
# Out:
# [{'labelsReleased': [['parking_lots'], []],
#   'has_panorama': 0,
#   'labels': ['Parkování'],
#   'is_auction': False,
#   'labelsAll': [['personal', 'brick', 'cellar', 'parking_lots'],
#    ['tavern',
#     'small_shop',
#     'candy_shop',
#     'vet',
#     'playground',
#     'movies',
#     'natural_attraction',
#     'theater',
#     'shop',
#     'drugstore',
#     'post_office',
#     'medic',
#     'bus_public_transport',
#     'tram',
#     'restaurant',
#     'train',
#     'sports',
#     'metro',
#     'kindergarten',
#     'atm',
#     'school']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 8,
#    'category_type_cb': 1,
#    'locality': 'praha-strasnice-'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/662340940',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/662340940',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'YT-Luxury-Property-luxusni-byty-Praha-Praha-Nove-Mesto',
#     'id': 20710,
#     'name': 'Y&T Luxury Property – luxusní byty Praha',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_G_I/WK7Fdo.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 3 - Strašnice',
#   'has_video': False,
#   'advert_images_count': 5,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 662340940,
#   'attractive_offer': 0,
#   'price': 0,
#   'price_czk': {'value_raw': 0, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_K5/1KOaRc.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_K5/1KOaRc.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-20?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/662340940?region_tip=2839154'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_K5/1KOaRc.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jq/cFyhVw.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jr/9gWHg0.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jr/HcSHg1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LF/I6MglH.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_K5/1KOaRc.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 4+kk 55\xa0m²',
#   'region_tip': 2839154,
#   'gps': {'lat': 50.05896962336297, 'lon': 14.51637437663703},
#   'has_matterport_url': False},
#  {'labelsReleased': [['furnished'], []],
#   'has_panorama': 0,
#   'labels': ['Vybavený'],
#   'is_auction': False,
#   'labelsAll': [['personal', 'brick', 'cellar', 'elevator', 'furnished'],
#    ['tavern',
#     'candy_shop',
#     'small_shop',
#     'theater',
#     'vet',
#     'movies',
#     'playground',
#     'sightseeing',
#     'atm',
#     'bus_public_transport',
#     'drugstore',
#     'metro',
#     'restaurant',
#     'train',
#     'tram',
#     'school',
#     'post_office',
#     'medic',
#     'kindergarten',
#     'shop',
#     'sports']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 4,
#    'category_type_cb': 1,
#    'locality': 'praha-nove-mesto-skolska'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 0,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/3079939148',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/3079939148',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False}},
#   'paid_logo': 0,
#   'locality': 'Praha 1 - Nové Město',
#   'has_video': False,
#   'advert_images_count': 16,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 3079939148,
#   'attractive_offer': 0,
#   'price': 5526000,
#   'price_czk': {'value_raw': 5526000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J3/ef6KoV.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J3/ef6KoV.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-19?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/3079939148'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J3/ef6KoV.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jl/8w4Knv.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Ky/49XKsK.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J2/I4FKqS.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ld/vMDKqP.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J2/8v1KqT.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J3/ef6KoV.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+kk 30\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.073278623362974, 'lon': 14.43000437663703},
#   'has_matterport_url': False},
#  {'labelsReleased': [['after_reconstruction'], []],
#   'has_panorama': 0,
#   'labels': ['Po rekonstrukci'],
#   'is_auction': False,
#   'labelsAll': [['personal',
#     'after_reconstruction',
#     'brick',
#     'cellar',
#     'elevator',
#     'not_furnished'],
#    ['candy_shop',
#     'theater',
#     'small_shop',
#     'vet',
#     'tavern',
#     'movies',
#     'playground',
#     'natural_attraction',
#     'sightseeing',
#     'tram',
#     'atm',
#     'kindergarten',
#     'sports',
#     'metro',
#     'train',
#     'bus_public_transport',
#     'post_office',
#     'drugstore',
#     'medic',
#     'shop',
#     'school',
#     'restaurant']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 6,
#    'category_type_cb': 1,
#    'locality': 'praha-nove-mesto-reznicka'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/1289888844',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/1289888844',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False}},
#   'paid_logo': 0,
#   'locality': 'Praha 1 - Nové Město',
#   'has_video': False,
#   'advert_images_count': 22,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 1289888844,
#   'attractive_offer': 0,
#   'price': 7229000,
#   'price_czk': {'value_raw': 7229000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ld/dwQB4F.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ld/dwQB4F.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-18?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/1289888844'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ld/dwQB4F.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jm/iGBd43.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_La/SrIP31.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MB/ztnB5Z.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MJ/Lsoyu1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jh/MNkPve.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ld/dwQB4F.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 3+kk 38\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.07246262336297, 'lon': 14.43000237663703},
#   'has_matterport_url': False},
#  {'labelsReleased': [['in_construction', 'collective', 'balcony'], []],
#   'has_panorama': 0,
#   'labels': ['Ve výstavbě', 'Družstevní', 'Balkon'],
#   'is_auction': False,
#   'labelsAll': [['in_construction',
#     'collective',
#     'balcony',
#     'brick',
#     'not_furnished'],
#    ['small_shop',
#     'tavern',
#     'candy_shop',
#     'vet',
#     'playground',
#     'theater',
#     'natural_attraction',
#     'movies',
#     'bus_public_transport',
#     'drugstore',
#     'metro',
#     'school',
#     'shop',
#     'kindergarten',
#     'post_office',
#     'medic',
#     'atm',
#     'tram',
#     'train',
#     'sports',
#     'restaurant']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 4,
#    'category_type_cb': 1,
#    'locality': 'praha-praha-9-nad-krocinkou'},
#   'exclusively_at_rk': 1,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/290006348',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/290006348',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'RE-MAX-Partner-Praha-Reporyje',
#     'id': 17196,
#     'name': 'RE/MAX Partner',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QN_3/rSiLCT.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 9',
#   'has_video': False,
#   'advert_images_count': 6,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 290006348,
#   'attractive_offer': 0,
#   'price': 0,
#   'price_czk': {'value_raw': 0, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/4aVmLG.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/4aVmLG.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-17?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/290006348'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/4aVmLG.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/AcLmLH.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/JGonjb.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/H73mLJ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/Lhjzk2.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/RFiz0P.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/4aVmLG.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+kk 29\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.11171162336297, 'lon': 14.491121376637029},
#   'has_matterport_url': False},
#  {'labelsReleased': [['terrace', 'partly_furnished'], []],
#   'has_panorama': 0,
#   'labels': ['Terasa', 'Částečně vybavený'],
#   'is_auction': False,
#   'labelsAll': [['personal',
#     'terrace',
#     'brick',
#     'elevator',
#     'partly_furnished'],
#    ['tavern',
#     'candy_shop',
#     'small_shop',
#     'theater',
#     'vet',
#     'movies',
#     'playground',
#     'sightseeing',
#     'metro',
#     'restaurant',
#     'school',
#     'shop',
#     'atm',
#     'train',
#     'medic',
#     'sports',
#     'kindergarten',
#     'drugstore',
#     'bus_public_transport',
#     'tram',
#     'post_office']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 5,
#    'category_type_cb': 1,
#    'locality': 'praha-nove-mesto-skolska'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 0,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/2725778764',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/2725778764',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False}},
#   'paid_logo': 0,
#   'locality': 'Praha 1 - Nové Město',
#   'has_video': False,
#   'advert_images_count': 19,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 2725778764,
#   'attractive_offer': 0,
#   'price': 7536000,
#   'price_czk': {'value_raw': 7536000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/eVkXux.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/eVkXux.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-16?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/2725778764'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/eVkXux.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/L9ULol.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/CB6KSd.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ls/06XXyG.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/uNOX4X.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/M0bXuv.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/eVkXux.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+1\xa032\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.073278623362974, 'lon': 14.43000437663703},
#   'has_matterport_url': False},
#  {'labelsReleased': [['partly_furnished'], ['train', 'post_office']],
#   'has_panorama': 0,
#   'labels': ['Částečně vybavený', 'Vlak 6 min. pěšky', 'Pošta 6 min. pěšky'],
#   'is_auction': False,
#   'labelsAll': [['personal', 'brick', 'partly_furnished'],
#    ['small_shop',
#     'candy_shop',
#     'theater',
#     'tavern',
#     'vet',
#     'movies',
#     'playground',
#     'sightseeing',
#     'restaurant',
#     'post_office',
#     'metro',
#     'school',
#     'atm',
#     'drugstore',
#     'tram',
#     'kindergarten',
#     'medic',
#     'train',
#     'shop',
#     'sports',
#     'bus_public_transport']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 4,
#    'category_type_cb': 1,
#    'locality': 'praha-nusle-mecislavova'},
#   'exclusively_at_rk': 1,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/3052594508',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/3052594508',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False}},
#   'paid_logo': 0,
#   'locality': 'Praha 4 - Nusle',
#   'has_video': True,
#   'advert_images_count': 18,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 3052594508,
#   'attractive_offer': 0,
#   'price': 3181000,
#   'price_czk': {'value_raw': 3181000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_z/HYQDTS.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_z/HYQDTS.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-15?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/3052594508'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_z/HYQDTS.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/TadDTN.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gT_3/qF5DR3.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_z/OytDS2.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/Mj3HfF.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MN/LeMHd0.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_z/HYQDTS.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+kk 28\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.05916462336297, 'lon': 14.44985137663703},
#   'has_matterport_url': False},
#  {'labelsReleased': [[], ['post_office']],
#   'has_panorama': 0,
#   'labels': ['Pošta 2 min. pěšky'],
#   'is_auction': False,
#   'labelsAll': [['new_building', 'personal'],
#    ['small_shop',
#     'tavern',
#     'movies',
#     'candy_shop',
#     'theater',
#     'vet',
#     'playground',
#     'natural_attraction',
#     'metro',
#     'drugstore',
#     'post_office',
#     'kindergarten',
#     'sports',
#     'tram',
#     'shop',
#     'medic',
#     'restaurant',
#     'train',
#     'atm',
#     'school',
#     'bus_public_transport']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 4,
#    'category_type_cb': 1,
#    'locality': 'praha-stodulky-habova'},
#   'exclusively_at_rk': 1,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/3075359820',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/3075359820',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'Trigema-a-s-Praha-Stodulky',
#     'id': 2995,
#     'name': 'Trigema a.s.',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gW_f/UoZMGF.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 5 - Stodůlky',
#   'has_video': False,
#   'advert_images_count': 12,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 3075359820,
#   'attractive_offer': 0,
#   'price': 4119000,
#   'price_czk': {'value_raw': 4119000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jt/vCKZaF.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jt/vCKZaF.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-14?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/3075359820'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jt/vCKZaF.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Ju/FRGZHM.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_K8/pc5ZJX.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_ML/xcFZNa.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jo/RdDZI6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KE/G4JZKr.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jt/vCKZaF.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+kk 24\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.04077762336297, 'lon': 14.31613837663703},
#   'has_matterport_url': False},
#  {'labelsReleased': [['balcony', 'parking_lots'], []],
#   'has_panorama': 0,
#   'labels': ['Balkon', 'Parkování'],
#   'is_auction': False,
#   'labelsAll': [['new_building',
#     'personal',
#     'balcony',
#     'cellar',
#     'elevator',
#     'parking_lots'],
#    ['small_shop',
#     'vet',
#     'candy_shop',
#     'tavern',
#     'theater',
#     'playground',
#     'movies',
#     'shop',
#     'school',
#     'sports',
#     'tram',
#     'drugstore',
#     'kindergarten',
#     'medic',
#     'bus_public_transport',
#     'train',
#     'atm',
#     'post_office',
#     'restaurant',
#     'metro']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 4,
#    'category_type_cb': 1,
#    'locality': 'praha-praha-cakovice-belomlynska'},
#   'exclusively_at_rk': 1,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/547366220',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/547366220',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'Sekyra-Group-a-s-Praha-Karlin',
#     'id': 3360,
#     'name': 'Sekyra Group, a.s.',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QI_g/RYpNU.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 9 - Praha-Čakovice',
#   'has_video': False,
#   'advert_images_count': 5,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 547366220,
#   'attractive_offer': 0,
#   'price': 3571000,
#   'price_czk': {'value_raw': 3571000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/AxeSgT.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/AxeSgT.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-13?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/547366220'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/AxeSgT.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/j8rSbP.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/tjWhO6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_z/aV0SjU.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_z/svoSjV.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/AxeSgT.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+kk 29\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.15230462336297, 'lon': 14.53236737663703},
#   'has_matterport_url': False},
#  {'labelsReleased': [['collective'], []],
#   'has_panorama': 0,
#   'labels': ['Družstevní'],
#   'is_auction': False,
#   'labelsAll': [['collective', 'brick', 'cellar', 'elevator'],
#    ['small_shop',
#     'candy_shop',
#     'vet',
#     'theater',
#     'tavern',
#     'movies',
#     'playground',
#     'natural_attraction',
#     'sightseeing',
#     'atm',
#     'metro',
#     'post_office',
#     'kindergarten',
#     'drugstore',
#     'shop',
#     'school',
#     'medic',
#     'sports',
#     'bus_public_transport',
#     'tram',
#     'train',
#     'restaurant']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 4,
#    'category_type_cb': 1,
#    'locality': 'praha-vinohrady-hradecka'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/1694820172',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/1694820172',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'Duna-House-Praha-Michle',
#     'id': 43314,
#     'name': 'Duna House',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QJ_g/AKtCu.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 3 - Vinohrady',
#   'has_video': False,
#   'advert_images_count': 10,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 1694820172,
#   'attractive_offer': 0,
#   'price': 6135000,
#   'price_czk': {'value_raw': 6135000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/9rlzlp.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/9rlzlp.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-12?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/1694820172'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/9rlzlp.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jx/sOeYeZ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/wjLzlq.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/ddPmJD.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/spzng5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/d2jziB.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/9rlzlp.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+kk 36\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.07100862336297, 'lon': 14.46946937663703},
#   'has_matterport_url': False},
#  {'labelsReleased': [['loggia', 'panel'], ['train']],
#   'has_panorama': 0,
#   'labels': ['Lodžie', 'Panelová', 'Vlak 5 min. pěšky'],
#   'is_auction': False,
#   'labelsAll': [['personal', 'loggia', 'panel', 'cellar', 'elevator'],
#    ['small_shop',
#     'vet',
#     'tavern',
#     'candy_shop',
#     'theater',
#     'playground',
#     'natural_attraction',
#     'movies',
#     'shop',
#     'train',
#     'restaurant',
#     'atm',
#     'drugstore',
#     'bus_public_transport',
#     'tram',
#     'sports',
#     'medic',
#     'post_office',
#     'metro',
#     'kindergarten',
#     'school']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 7,
#    'category_type_cb': 1,
#    'locality': 'praha-repy-vondrousova'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/566302028',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/566302028',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False}},
#   'paid_logo': 0,
#   'locality': 'Praha 6 - Řepy',
#   'has_video': False,
#   'advert_images_count': 19,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 566302028,
#   'attractive_offer': 0,
#   'price': 3851000,
#   'price_czk': {'value_raw': 3851000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/i71Y8O.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/i71Y8O.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-11?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/566302028'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/i71Y8O.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_z/RlMZAE.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/IXQhXg.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/9Wbta1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_0/BqhZDy.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/gLXY2Q.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/i71Y8O.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 3+1\xa045\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.05858462336297, 'lon': 14.30650237663703},
#   'has_matterport_url': False},
#  {'labelsReleased': [['partly_furnished'], ['post_office']],
#   'has_panorama': 0,
#   'labels': ['Částečně vybavený', 'Pošta 1 min. pěšky'],
#   'is_auction': False,
#   'labelsAll': [['personal', 'brick', 'cellar', 'partly_furnished'],
#    ['candy_shop',
#     'small_shop',
#     'theater',
#     'tavern',
#     'vet',
#     'movies',
#     'playground',
#     'natural_attraction',
#     'sightseeing',
#     'sports',
#     'metro',
#     'medic',
#     'bus_public_transport',
#     'school',
#     'tram',
#     'drugstore',
#     'restaurant',
#     'shop',
#     'post_office',
#     'kindergarten',
#     'train',
#     'atm']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 7,
#    'category_type_cb': 1,
#    'locality': 'praha-smichov-ostrovskeho'},
#   'exclusively_at_rk': 1,
#   'category': 1,
#   'has_floor_plan': 0,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/3828229452',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/3828229452',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'Realitni-expert-Ing-Lucie-Mekhail-Lany',
#     'id': 43446,
#     'name': 'Realitní expert Ing. Lucie Mekhail',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gW_g/FIgBLy.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 5 - Smíchov',
#   'has_video': False,
#   'advert_images_count': 15,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 3828229452,
#   'attractive_offer': 0,
#   'price': 6363000,
#   'price_czk': {'value_raw': 6363000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/noLBIu.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/noLBIu.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-10?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/3828229452'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/noLBIu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/H2GBIU.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ls/HiSCJE.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/l0EBIv.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LM/0FbCIi.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_z/RoeBJc.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/noLBIu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 3+1\xa049\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.06300162336297, 'lon': 14.40556537663703},
#   'has_matterport_url': False},
#  {'labelsReleased': [['after_reconstruction', 'furnished'], ['shop']],
#   'has_panorama': 0,
#   'labels': ['Po rekonstrukci', 'Vybavený', 'Obchod 5 min. pěšky'],
#   'is_auction': False,
#   'labelsAll': [['personal',
#     'after_reconstruction',
#     'brick',
#     'elevator',
#     'furnished'],
#    ['tavern',
#     'candy_shop',
#     'theater',
#     'small_shop',
#     'vet',
#     'movies',
#     'playground',
#     'natural_attraction',
#     'sightseeing',
#     'restaurant',
#     'medic',
#     'kindergarten',
#     'metro',
#     'post_office',
#     'bus_public_transport',
#     'shop',
#     'school',
#     'train',
#     'drugstore',
#     'tram',
#     'atm',
#     'sports']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 7,
#    'category_type_cb': 1,
#    'locality': 'praha-stare-mesto-'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/4188198220',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/4188198220',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'REFA-Group-s-r-o-Praha-Zizkov',
#     'id': 15138,
#     'name': 'REFA Group s.r.o.',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gT_u/9gnCrW.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 1 - Staré Město',
#   'has_video': False,
#   'advert_images_count': 13,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 4188198220,
#   'attractive_offer': 0,
#   'price': 11103000,
#   'price_czk': {'value_raw': 11103000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/34BB129.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/34BB129.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-9?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/4188198220'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/34BB129.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LH/Wb4B1mK.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jt/gNPB1uF.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/VnxB13A.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_K7/k5YB1sk.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_K7/FFCB1sl.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/34BB129.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 3+1\xa049\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.07889362336297, 'lon': 14.42329237663703},
#   'has_matterport_url': False},
#  {'labelsReleased': [['balcony', 'partly_furnished'], []],
#   'has_panorama': 0,
#   'labels': ['Balkon', 'Částečně vybavený'],
#   'is_auction': False,
#   'labelsAll': [['new_building',
#     'personal',
#     'balcony',
#     'brick',
#     'elevator',
#     'garage',
#     'partly_furnished'],
#    ['small_shop',
#     'tavern',
#     'candy_shop',
#     'vet',
#     'movies',
#     'theater',
#     'playground',
#     'natural_attraction',
#     'metro',
#     'medic',
#     'tram',
#     'shop',
#     'bus_public_transport',
#     'sports',
#     'atm',
#     'post_office',
#     'train',
#     'school',
#     'kindergarten',
#     'drugstore',
#     'restaurant']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 4,
#    'category_type_cb': 1,
#    'locality': 'praha-hostivar-rychtare-petrika'},
#   'exclusively_at_rk': 1,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/1581876556',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/1581876556',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'GEPARD-REALITY-Pallas-Athena-Praha-Karlin',
#     'id': 27595,
#     'name': 'GEPARD REALITY/Pallas Athena',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gS_q/LZWGxb.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 10 - Hostivař',
#   'has_video': True,
#   'advert_images_count': 20,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 1581876556,
#   'attractive_offer': 0,
#   'price': 3740000,
#   'price_czk': {'value_raw': 3740000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/2VbYCa.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/2VbYCa.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-8?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/1581876556'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/2VbYCa.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jn/BVSX2J.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Lp/aJhYHc.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J9/90KX6J.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J9/GerX6K.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Js/8L3YCu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/2VbYCa.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+kk 25\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.05015062336297, 'lon': 14.53087937663703},
#   'has_matterport_url': False},
#  {'labelsReleased': [['balcony'], []],
#   'has_panorama': 0,
#   'labels': ['Balkon'],
#   'is_auction': False,
#   'labelsAll': [['personal', 'balcony', 'brick', 'cellar'],
#    ['small_shop',
#     'vet',
#     'candy_shop',
#     'theater',
#     'tavern',
#     'movies',
#     'playground',
#     'sightseeing',
#     'atm',
#     'metro',
#     'drugstore',
#     'sports',
#     'shop',
#     'restaurant',
#     'bus_public_transport',
#     'kindergarten',
#     'medic',
#     'post_office',
#     'train',
#     'tram',
#     'school']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 6,
#    'category_type_cb': 1,
#    'locality': 'praha-nusle-zateckych'},
#   'exclusively_at_rk': 1,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/1206252876',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/1206252876',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False}},
#   'paid_logo': 0,
#   'locality': 'Praha 4 - Nusle',
#   'has_video': False,
#   'advert_images_count': 30,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 1206252876,
#   'attractive_offer': 0,
#   'price': 5520000,
#   'price_czk': {'value_raw': 5520000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/MMqz0r.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/MMqz0r.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-7?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/1206252876'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/MMqz0r.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/kyGatG.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/Z5enj5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/xRFHNM.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_0/CcVHPW.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/zk6nj4.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/MMqz0r.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 3+kk 41\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.05491462336297, 'lon': 14.43956137663703},
#   'has_matterport_url': False},
#  {'labelsReleased': [['balcony'], []],
#   'has_panorama': 0,
#   'labels': ['Balkon'],
#   'is_auction': False,
#   'labelsAll': [['personal', 'balcony', 'elevator', 'garage', 'not_furnished'],
#    ['small_shop',
#     'theater',
#     'candy_shop',
#     'vet',
#     'tavern',
#     'movies',
#     'sightseeing',
#     'playground',
#     'shop',
#     'medic',
#     'bus_public_transport',
#     'tram',
#     'sports',
#     'atm',
#     'post_office',
#     'metro',
#     'drugstore',
#     'school',
#     'train',
#     'restaurant',
#     'kindergarten']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 4,
#    'category_type_cb': 1,
#    'locality': 'praha-holesovice-jatecni'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/4054193484',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/4054193484',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'CREDITAS-Real-Estate-Praha-Jinonice',
#     'id': 27848,
#     'name': 'CREDITAS Real Estate',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_s/whOD0n.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 7 - Holešovice',
#   'has_video': False,
#   'advert_images_count': 7,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 4054193484,
#   'attractive_offer': 0,
#   'price': 4962000,
#   'price_czk': {'value_raw': 4962000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/HrrYmi.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/HrrYmi.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-6?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/4054193484'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/HrrYmi.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/T0zYrT.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/fzlT1c.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ls/fPDszf.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/E2fYrU.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_z/TqiYxW.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/HrrYmi.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+kk 26\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.09511062336297, 'lon': 14.45431837663703},
#   'has_matterport_url': False},
#  {'labelsReleased': [[], []],
#   'has_panorama': 0,
#   'labels': [],
#   'is_auction': False,
#   'labelsAll': [['personal', 'elevator', 'garage', 'not_furnished'],
#    ['small_shop',
#     'theater',
#     'vet',
#     'candy_shop',
#     'tavern',
#     'movies',
#     'sightseeing',
#     'playground',
#     'restaurant',
#     'school',
#     'metro',
#     'drugstore',
#     'train',
#     'tram',
#     'kindergarten',
#     'atm',
#     'bus_public_transport',
#     'sports',
#     'medic',
#     'post_office',
#     'shop']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 2,
#    'category_type_cb': 1,
#    'locality': 'praha-holesovice-jatecni'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/2544244044',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/2544244044',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'CREDITAS-Real-Estate-Praha-Jinonice',
#     'id': 27848,
#     'name': 'CREDITAS Real Estate',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_s/whOD0n.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 7 - Holešovice',
#   'has_video': False,
#   'advert_images_count': 7,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 2544244044,
#   'attractive_offer': 0,
#   'price': 3176000,
#   'price_czk': {'value_raw': 3176000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/n2dgph.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/n2dgph.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-5?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/2544244044'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/n2dgph.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/YffYrI.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/lbkYrJ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MN/zV5s2f.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MN/ak3s2g.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_0/yX3Ecu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/n2dgph.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 1+kk 15\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.09511062336297, 'lon': 14.45431837663703},
#   'has_matterport_url': False},
#  {'labelsReleased': [['loggia'], []],
#   'has_panorama': 0,
#   'labels': ['Lodžie'],
#   'is_auction': False,
#   'labelsAll': [['personal', 'loggia', 'elevator', 'garage', 'not_furnished'],
#    ['small_shop',
#     'theater',
#     'vet',
#     'candy_shop',
#     'tavern',
#     'movies',
#     'sightseeing',
#     'playground',
#     'restaurant',
#     'post_office',
#     'sports',
#     'kindergarten',
#     'medic',
#     'drugstore',
#     'train',
#     'tram',
#     'bus_public_transport',
#     'metro',
#     'atm',
#     'shop',
#     'school']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 6,
#    'category_type_cb': 1,
#    'locality': 'praha-holesovice-jatecni'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/2882934092',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/2882934092',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'CREDITAS-Real-Estate-Praha-Jinonice',
#     'id': 27848,
#     'name': 'CREDITAS Real Estate',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_s/whOD0n.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 7 - Holešovice',
#   'has_video': False,
#   'advert_images_count': 7,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 2882934092,
#   'attractive_offer': 0,
#   'price': 6135000,
#   'price_czk': {'value_raw': 6135000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/Hkisuf.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/Hkisuf.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-4?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/2882934092'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/Hkisuf.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/3kTYrK.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_z/mqgYxO.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/1estA3.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/vYJsug.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/mDRYsx.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/Hkisuf.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 3+kk 37\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.09511062336297, 'lon': 14.45431837663703},
#   'has_matterport_url': False},
#  {'labelsReleased': [[], []],
#   'has_panorama': 0,
#   'labels': [],
#   'is_auction': False,
#   'labelsAll': [['new_building',
#     'personal',
#     'brick',
#     'elevator',
#     'garage',
#     'not_furnished'],
#    ['candy_shop',
#     'tavern',
#     'small_shop',
#     'theater',
#     'movies',
#     'vet',
#     'playground',
#     'natural_attraction',
#     'sightseeing',
#     'tram',
#     'atm',
#     'bus_public_transport',
#     'shop',
#     'drugstore',
#     'metro',
#     'train',
#     'school',
#     'sports',
#     'medic',
#     'kindergarten',
#     'restaurant',
#     'post_office']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 4,
#    'category_type_cb': 1,
#    'locality': 'praha-jinonice-reporyjska'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 0,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/487134540',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/487134540',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'CREDITAS-Real-Estate-Praha-Jinonice',
#     'id': 27848,
#     'name': 'CREDITAS Real Estate',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_s/whOD0n.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 5 - Jinonice',
#   'has_video': False,
#   'advert_images_count': 16,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 487134540,
#   'attractive_offer': 0,
#   'price': 6567000,
#   'price_czk': {'value_raw': 6567000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jq/IpxWTn.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jq/IpxWTn.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-3?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/487134540'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jq/IpxWTn.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/d59WXc.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/J9hMv6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/WdLMsH.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/n29I8B.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/JkfWbh.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jq/IpxWTn.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+kk 48\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.04587062336297, 'lon': 14.36083637663703},
#   'has_matterport_url': False},
#  {'labelsReleased': [[], []],
#   'has_panorama': 0,
#   'labels': [],
#   'is_auction': False,
#   'labelsAll': [['new_building',
#     'personal',
#     'brick',
#     'garage',
#     'not_furnished'],
#    ['candy_shop',
#     'tavern',
#     'small_shop',
#     'theater',
#     'movies',
#     'playground',
#     'vet',
#     'natural_attraction',
#     'sightseeing',
#     'post_office',
#     'sports',
#     'atm',
#     'train',
#     'shop',
#     'medic',
#     'tram',
#     'restaurant',
#     'bus_public_transport',
#     'drugstore',
#     'school',
#     'kindergarten',
#     'metro']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 6,
#    'category_type_cb': 1,
#    'locality': 'praha-jinonice-reporyjska'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 0,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/1379472716',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/1379472716',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'CREDITAS-Real-Estate-Praha-Jinonice',
#     'id': 27848,
#     'name': 'CREDITAS Real Estate',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_s/whOD0n.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 5 - Jinonice',
#   'has_video': False,
#   'advert_images_count': 14,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 1379472716,
#   'attractive_offer': 0,
#   'price': 8084000,
#   'price_czk': {'value_raw': 8084000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/14mKRt.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/14mKRt.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-2?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/1379472716'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/14mKRt.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jq/kKBWN9.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/uftMsC.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gQ_0/PQnMnK.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/u6fKRu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jw/wMBWQ6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/14mKRt.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 3+kk 60\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.04587062336297, 'lon': 14.36083637663703},
#   'has_matterport_url': False},
#  {'labelsReleased': [[], []],
#   'has_panorama': 0,
#   'labels': [],
#   'is_auction': False,
#   'labelsAll': [['new_building',
#     'personal',
#     'brick',
#     'garage',
#     'not_furnished'],
#    ['candy_shop',
#     'tavern',
#     'small_shop',
#     'theater',
#     'movies',
#     'playground',
#     'vet',
#     'natural_attraction',
#     'sightseeing',
#     'drugstore',
#     'shop',
#     'sports',
#     'atm',
#     'school',
#     'kindergarten',
#     'medic',
#     'train',
#     'bus_public_transport',
#     'tram',
#     'restaurant',
#     'metro',
#     'post_office']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 4,
#    'category_type_cb': 1,
#    'locality': 'praha-jinonice-reporyjska'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 0,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/2604209484',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/2604209484',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'CREDITAS-Real-Estate-Praha-Jinonice',
#     'id': 27848,
#     'name': 'CREDITAS Real Estate',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_s/whOD0n.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 5 - Jinonice',
#   'has_video': False,
#   'advert_images_count': 13,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 2604209484,
#   'attractive_offer': 0,
#   'price': 5051000,
#   'price_czk': {'value_raw': 5051000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/C1BI3h.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/C1BI3h.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-1?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/2604209484'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/C1BI3h.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/32qWeZ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_0/8GNMsy.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_z/eXAMwq.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/o4eWdL.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/e5wWW9.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/C1BI3h.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+kk 36\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.04587062336297, 'lon': 14.36083637663703},
#   'has_matterport_url': False},
#  {'labelsReleased': [[], []],
#   'has_panorama': 0,
#   'labels': [],
#   'is_auction': False,
#   'labelsAll': [['new_building',
#     'personal',
#     'brick',
#     'garage',
#     'not_furnished'],
#    ['candy_shop',
#     'tavern',
#     'small_shop',
#     'theater',
#     'movies',
#     'vet',
#     'playground',
#     'natural_attraction',
#     'sightseeing',
#     'train',
#     'medic',
#     'school',
#     'post_office',
#     'sports',
#     'tram',
#     'drugstore',
#     'kindergarten',
#     'shop',
#     'bus_public_transport',
#     'metro',
#     'restaurant',
#     'atm']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 6,
#    'category_type_cb': 1,
#    'locality': 'praha-jinonice-reporyjska'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/2704872780',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/2704872780',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'CREDITAS-Real-Estate-Praha-Jinonice',
#     'id': 27848,
#     'name': 'CREDITAS Real Estate',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_s/whOD0n.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 5 - Jinonice',
#   'has_video': False,
#   'advert_images_count': 15,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 2704872780,
#   'attractive_offer': 0,
#   'price': 7326000,
#   'price_czk': {'value_raw': 7326000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/FTOI2A.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/FTOI2A.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/0?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/2704872780'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/FTOI2A.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_z/0WGMxe.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gQ_0/W18Mmq.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/RhhWbd.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/JlPWVX.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/DM0MsM.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/FTOI2A.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 3+kk 51\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.04587062336297, 'lon': 14.36083637663703},
#   'has_matterport_url': False}]

# %%
d['_embedded']
# Out:
# {'estates': [{'labelsReleased': [['parking_lots'], []],
#    'has_panorama': 0,
#    'labels': ['Parkování'],
#    'is_auction': False,
#    'labelsAll': [['personal', 'brick', 'cellar', 'parking_lots'],
#     ['tavern',
#      'small_shop',
#      'candy_shop',
#      'vet',
#      'playground',
#      'movies',
#      'natural_attraction',
#      'theater',
#      'shop',
#      'drugstore',
#      'post_office',
#      'medic',
#      'bus_public_transport',
#      'tram',
#      'restaurant',
#      'train',
#      'sports',
#      'metro',
#      'kindergarten',
#      'atm',
#      'school']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 8,
#     'category_type_cb': 1,
#     'locality': 'praha-strasnice-'},
#    'exclusively_at_rk': 0,
#    'category': 1,
#    'has_floor_plan': 1,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/662340940',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/662340940',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False},
#     'company': {'url': 'YT-Luxury-Property-luxusni-byty-Praha-Praha-Nove-Mesto',
#      'id': 20710,
#      'name': 'Y&T Luxury Property – luxusní byty Praha',
#      'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_G_I/WK7Fdo.png?fl=res,140,140,3,ffffff'}},
#    'paid_logo': 1,
#    'locality': 'Praha 3 - Strašnice',
#    'has_video': False,
#    'advert_images_count': 5,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 662340940,
#    'attractive_offer': 0,
#    'price': 0,
#    'price_czk': {'value_raw': 0, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_K5/1KOaRc.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_K5/1KOaRc.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/-20?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/662340940?region_tip=2839154'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_K5/1KOaRc.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jq/cFyhVw.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jr/9gWHg0.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jr/HcSHg1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LF/I6MglH.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_K5/1KOaRc.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 4+kk 55\xa0m²',
#    'region_tip': 2839154,
#    'gps': {'lat': 50.05896962336297, 'lon': 14.51637437663703},
#    'has_matterport_url': False},
#   {'labelsReleased': [['furnished'], []],
#    'has_panorama': 0,
#    'labels': ['Vybavený'],
#    'is_auction': False,
#    'labelsAll': [['personal', 'brick', 'cellar', 'elevator', 'furnished'],
#     ['tavern',
#      'candy_shop',
#      'small_shop',
#      'theater',
#      'vet',
#      'movies',
#      'playground',
#      'sightseeing',
#      'atm',
#      'bus_public_transport',
#      'drugstore',
#      'metro',
#      'restaurant',
#      'train',
#      'tram',
#      'school',
#      'post_office',
#      'medic',
#      'kindergarten',
#      'shop',
#      'sports']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 4,
#     'category_type_cb': 1,
#     'locality': 'praha-nove-mesto-skolska'},
#    'exclusively_at_rk': 0,
#    'category': 1,
#    'has_floor_plan': 0,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/3079939148',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/3079939148',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False}},
#    'paid_logo': 0,
#    'locality': 'Praha 1 - Nové Město',
#    'has_video': False,
#    'advert_images_count': 16,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 3079939148,
#    'attractive_offer': 0,
#    'price': 5526000,
#    'price_czk': {'value_raw': 5526000, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J3/ef6KoV.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J3/ef6KoV.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/-19?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/3079939148'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J3/ef6KoV.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jl/8w4Knv.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Ky/49XKsK.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J2/I4FKqS.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ld/vMDKqP.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J2/8v1KqT.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J3/ef6KoV.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 2+kk 30\xa0m²',
#    'region_tip': 0,
#    'gps': {'lat': 50.073278623362974, 'lon': 14.43000437663703},
#    'has_matterport_url': False},
#   {'labelsReleased': [['after_reconstruction'], []],
#    'has_panorama': 0,
#    'labels': ['Po rekonstrukci'],
#    'is_auction': False,
#    'labelsAll': [['personal',
#      'after_reconstruction',
#      'brick',
#      'cellar',
#      'elevator',
#      'not_furnished'],
#     ['candy_shop',
#      'theater',
#      'small_shop',
#      'vet',
#      'tavern',
#      'movies',
#      'playground',
#      'natural_attraction',
#      'sightseeing',
#      'tram',
#      'atm',
#      'kindergarten',
#      'sports',
#      'metro',
#      'train',
#      'bus_public_transport',
#      'post_office',
#      'drugstore',
#      'medic',
#      'shop',
#      'school',
#      'restaurant']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 6,
#     'category_type_cb': 1,
#     'locality': 'praha-nove-mesto-reznicka'},
#    'exclusively_at_rk': 0,
#    'category': 1,
#    'has_floor_plan': 1,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/1289888844',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/1289888844',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False}},
#    'paid_logo': 0,
#    'locality': 'Praha 1 - Nové Město',
#    'has_video': False,
#    'advert_images_count': 22,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 1289888844,
#    'attractive_offer': 0,
#    'price': 7229000,
#    'price_czk': {'value_raw': 7229000, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ld/dwQB4F.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ld/dwQB4F.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/-18?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/1289888844'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ld/dwQB4F.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jm/iGBd43.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_La/SrIP31.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MB/ztnB5Z.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MJ/Lsoyu1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jh/MNkPve.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ld/dwQB4F.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 3+kk 38\xa0m²',
#    'region_tip': 0,
#    'gps': {'lat': 50.07246262336297, 'lon': 14.43000237663703},
#    'has_matterport_url': False},
#   {'labelsReleased': [['in_construction', 'collective', 'balcony'], []],
#    'has_panorama': 0,
#    'labels': ['Ve výstavbě', 'Družstevní', 'Balkon'],
#    'is_auction': False,
#    'labelsAll': [['in_construction',
#      'collective',
#      'balcony',
#      'brick',
#      'not_furnished'],
#     ['small_shop',
#      'tavern',
#      'candy_shop',
#      'vet',
#      'playground',
#      'theater',
#      'natural_attraction',
#      'movies',
#      'bus_public_transport',
#      'drugstore',
#      'metro',
#      'school',
#      'shop',
#      'kindergarten',
#      'post_office',
#      'medic',
#      'atm',
#      'tram',
#      'train',
#      'sports',
#      'restaurant']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 4,
#     'category_type_cb': 1,
#     'locality': 'praha-praha-9-nad-krocinkou'},
#    'exclusively_at_rk': 1,
#    'category': 1,
#    'has_floor_plan': 1,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/290006348',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/290006348',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False},
#     'company': {'url': 'RE-MAX-Partner-Praha-Reporyje',
#      'id': 17196,
#      'name': 'RE/MAX Partner',
#      'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QN_3/rSiLCT.png?fl=res,140,140,3,ffffff'}},
#    'paid_logo': 1,
#    'locality': 'Praha 9',
#    'has_video': False,
#    'advert_images_count': 6,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 290006348,
#    'attractive_offer': 0,
#    'price': 0,
#    'price_czk': {'value_raw': 0, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/4aVmLG.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/4aVmLG.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/-17?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/290006348'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/4aVmLG.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/AcLmLH.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/JGonjb.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/H73mLJ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/Lhjzk2.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/RFiz0P.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/4aVmLG.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 2+kk 29\xa0m²',
#    'region_tip': 0,
#    'gps': {'lat': 50.11171162336297, 'lon': 14.491121376637029},
#    'has_matterport_url': False},
#   {'labelsReleased': [['terrace', 'partly_furnished'], []],
#    'has_panorama': 0,
#    'labels': ['Terasa', 'Částečně vybavený'],
#    'is_auction': False,
#    'labelsAll': [['personal',
#      'terrace',
#      'brick',
#      'elevator',
#      'partly_furnished'],
#     ['tavern',
#      'candy_shop',
#      'small_shop',
#      'theater',
#      'vet',
#      'movies',
#      'playground',
#      'sightseeing',
#      'metro',
#      'restaurant',
#      'school',
#      'shop',
#      'atm',
#      'train',
#      'medic',
#      'sports',
#      'kindergarten',
#      'drugstore',
#      'bus_public_transport',
#      'tram',
#      'post_office']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 5,
#     'category_type_cb': 1,
#     'locality': 'praha-nove-mesto-skolska'},
#    'exclusively_at_rk': 0,
#    'category': 1,
#    'has_floor_plan': 0,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/2725778764',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/2725778764',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False}},
#    'paid_logo': 0,
#    'locality': 'Praha 1 - Nové Město',
#    'has_video': False,
#    'advert_images_count': 19,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 2725778764,
#    'attractive_offer': 0,
#    'price': 7536000,
#    'price_czk': {'value_raw': 7536000, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/eVkXux.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/eVkXux.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/-16?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/2725778764'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/eVkXux.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/L9ULol.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/CB6KSd.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ls/06XXyG.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/uNOX4X.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/M0bXuv.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/eVkXux.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 2+1\xa032\xa0m²',
#    'region_tip': 0,
#    'gps': {'lat': 50.073278623362974, 'lon': 14.43000437663703},
#    'has_matterport_url': False},
#   {'labelsReleased': [['partly_furnished'], ['train', 'post_office']],
#    'has_panorama': 0,
#    'labels': ['Částečně vybavený', 'Vlak 6 min. pěšky', 'Pošta 6 min. pěšky'],
#    'is_auction': False,
#    'labelsAll': [['personal', 'brick', 'partly_furnished'],
#     ['small_shop',
#      'candy_shop',
#      'theater',
#      'tavern',
#      'vet',
#      'movies',
#      'playground',
#      'sightseeing',
#      'restaurant',
#      'post_office',
#      'metro',
#      'school',
#      'atm',
#      'drugstore',
#      'tram',
#      'kindergarten',
#      'medic',
#      'train',
#      'shop',
#      'sports',
#      'bus_public_transport']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 4,
#     'category_type_cb': 1,
#     'locality': 'praha-nusle-mecislavova'},
#    'exclusively_at_rk': 1,
#    'category': 1,
#    'has_floor_plan': 1,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/3052594508',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/3052594508',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False}},
#    'paid_logo': 0,
#    'locality': 'Praha 4 - Nusle',
#    'has_video': True,
#    'advert_images_count': 18,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 3052594508,
#    'attractive_offer': 0,
#    'price': 3181000,
#    'price_czk': {'value_raw': 3181000, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_z/HYQDTS.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_z/HYQDTS.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/-15?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/3052594508'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_z/HYQDTS.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/TadDTN.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gT_3/qF5DR3.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_z/OytDS2.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/Mj3HfF.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MN/LeMHd0.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_z/HYQDTS.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 2+kk 28\xa0m²',
#    'region_tip': 0,
#    'gps': {'lat': 50.05916462336297, 'lon': 14.44985137663703},
#    'has_matterport_url': False},
#   {'labelsReleased': [[], ['post_office']],
#    'has_panorama': 0,
#    'labels': ['Pošta 2 min. pěšky'],
#    'is_auction': False,
#    'labelsAll': [['new_building', 'personal'],
#     ['small_shop',
#      'tavern',
#      'movies',
#      'candy_shop',
#      'theater',
#      'vet',
#      'playground',
#      'natural_attraction',
#      'metro',
#      'drugstore',
#      'post_office',
#      'kindergarten',
#      'sports',
#      'tram',
#      'shop',
#      'medic',
#      'restaurant',
#      'train',
#      'atm',
#      'school',
#      'bus_public_transport']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 4,
#     'category_type_cb': 1,
#     'locality': 'praha-stodulky-habova'},
#    'exclusively_at_rk': 1,
#    'category': 1,
#    'has_floor_plan': 1,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/3075359820',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/3075359820',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False},
#     'company': {'url': 'Trigema-a-s-Praha-Stodulky',
#      'id': 2995,
#      'name': 'Trigema a.s.',
#      'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gW_f/UoZMGF.png?fl=res,140,140,3,ffffff'}},
#    'paid_logo': 1,
#    'locality': 'Praha 5 - Stodůlky',
#    'has_video': False,
#    'advert_images_count': 12,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 3075359820,
#    'attractive_offer': 0,
#    'price': 4119000,
#    'price_czk': {'value_raw': 4119000, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jt/vCKZaF.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jt/vCKZaF.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/-14?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/3075359820'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jt/vCKZaF.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Ju/FRGZHM.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_K8/pc5ZJX.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_ML/xcFZNa.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jo/RdDZI6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KE/G4JZKr.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jt/vCKZaF.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 2+kk 24\xa0m²',
#    'region_tip': 0,
#    'gps': {'lat': 50.04077762336297, 'lon': 14.31613837663703},
#    'has_matterport_url': False},
#   {'labelsReleased': [['balcony', 'parking_lots'], []],
#    'has_panorama': 0,
#    'labels': ['Balkon', 'Parkování'],
#    'is_auction': False,
#    'labelsAll': [['new_building',
#      'personal',
#      'balcony',
#      'cellar',
#      'elevator',
#      'parking_lots'],
#     ['small_shop',
#      'vet',
#      'candy_shop',
#      'tavern',
#      'theater',
#      'playground',
#      'movies',
#      'shop',
#      'school',
#      'sports',
#      'tram',
#      'drugstore',
#      'kindergarten',
#      'medic',
#      'bus_public_transport',
#      'train',
#      'atm',
#      'post_office',
#      'restaurant',
#      'metro']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 4,
#     'category_type_cb': 1,
#     'locality': 'praha-praha-cakovice-belomlynska'},
#    'exclusively_at_rk': 1,
#    'category': 1,
#    'has_floor_plan': 1,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/547366220',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/547366220',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False},
#     'company': {'url': 'Sekyra-Group-a-s-Praha-Karlin',
#      'id': 3360,
#      'name': 'Sekyra Group, a.s.',
#      'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QI_g/RYpNU.png?fl=res,140,140,3,ffffff'}},
#    'paid_logo': 1,
#    'locality': 'Praha 9 - Praha-Čakovice',
#    'has_video': False,
#    'advert_images_count': 5,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 547366220,
#    'attractive_offer': 0,
#    'price': 3571000,
#    'price_czk': {'value_raw': 3571000, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/AxeSgT.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/AxeSgT.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/-13?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/547366220'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/AxeSgT.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/j8rSbP.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/tjWhO6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_z/aV0SjU.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_z/svoSjV.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/AxeSgT.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 2+kk 29\xa0m²',
#    'region_tip': 0,
#    'gps': {'lat': 50.15230462336297, 'lon': 14.53236737663703},
#    'has_matterport_url': False},
#   {'labelsReleased': [['collective'], []],
#    'has_panorama': 0,
#    'labels': ['Družstevní'],
#    'is_auction': False,
#    'labelsAll': [['collective', 'brick', 'cellar', 'elevator'],
#     ['small_shop',
#      'candy_shop',
#      'vet',
#      'theater',
#      'tavern',
#      'movies',
#      'playground',
#      'natural_attraction',
#      'sightseeing',
#      'atm',
#      'metro',
#      'post_office',
#      'kindergarten',
#      'drugstore',
#      'shop',
#      'school',
#      'medic',
#      'sports',
#      'bus_public_transport',
#      'tram',
#      'train',
#      'restaurant']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 4,
#     'category_type_cb': 1,
#     'locality': 'praha-vinohrady-hradecka'},
#    'exclusively_at_rk': 0,
#    'category': 1,
#    'has_floor_plan': 1,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/1694820172',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/1694820172',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False},
#     'company': {'url': 'Duna-House-Praha-Michle',
#      'id': 43314,
#      'name': 'Duna House',
#      'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QJ_g/AKtCu.png?fl=res,140,140,3,ffffff'}},
#    'paid_logo': 1,
#    'locality': 'Praha 3 - Vinohrady',
#    'has_video': False,
#    'advert_images_count': 10,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 1694820172,
#    'attractive_offer': 0,
#    'price': 6135000,
#    'price_czk': {'value_raw': 6135000, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/9rlzlp.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/9rlzlp.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/-12?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/1694820172'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/9rlzlp.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jx/sOeYeZ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/wjLzlq.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/ddPmJD.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/spzng5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/d2jziB.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/9rlzlp.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 2+kk 36\xa0m²',
#    'region_tip': 0,
#    'gps': {'lat': 50.07100862336297, 'lon': 14.46946937663703},
#    'has_matterport_url': False},
#   {'labelsReleased': [['loggia', 'panel'], ['train']],
#    'has_panorama': 0,
#    'labels': ['Lodžie', 'Panelová', 'Vlak 5 min. pěšky'],
#    'is_auction': False,
#    'labelsAll': [['personal', 'loggia', 'panel', 'cellar', 'elevator'],
#     ['small_shop',
#      'vet',
#      'tavern',
#      'candy_shop',
#      'theater',
#      'playground',
#      'natural_attraction',
#      'movies',
#      'shop',
#      'train',
#      'restaurant',
#      'atm',
#      'drugstore',
#      'bus_public_transport',
#      'tram',
#      'sports',
#      'medic',
#      'post_office',
#      'metro',
#      'kindergarten',
#      'school']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 7,
#     'category_type_cb': 1,
#     'locality': 'praha-repy-vondrousova'},
#    'exclusively_at_rk': 0,
#    'category': 1,
#    'has_floor_plan': 1,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/566302028',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/566302028',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False}},
#    'paid_logo': 0,
#    'locality': 'Praha 6 - Řepy',
#    'has_video': False,
#    'advert_images_count': 19,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 566302028,
#    'attractive_offer': 0,
#    'price': 3851000,
#    'price_czk': {'value_raw': 3851000, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/i71Y8O.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/i71Y8O.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/-11?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/566302028'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/i71Y8O.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_z/RlMZAE.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/IXQhXg.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/9Wbta1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_0/BqhZDy.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/gLXY2Q.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/i71Y8O.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 3+1\xa045\xa0m²',
#    'region_tip': 0,
#    'gps': {'lat': 50.05858462336297, 'lon': 14.30650237663703},
#    'has_matterport_url': False},
#   {'labelsReleased': [['partly_furnished'], ['post_office']],
#    'has_panorama': 0,
#    'labels': ['Částečně vybavený', 'Pošta 1 min. pěšky'],
#    'is_auction': False,
#    'labelsAll': [['personal', 'brick', 'cellar', 'partly_furnished'],
#     ['candy_shop',
#      'small_shop',
#      'theater',
#      'tavern',
#      'vet',
#      'movies',
#      'playground',
#      'natural_attraction',
#      'sightseeing',
#      'sports',
#      'metro',
#      'medic',
#      'bus_public_transport',
#      'school',
#      'tram',
#      'drugstore',
#      'restaurant',
#      'shop',
#      'post_office',
#      'kindergarten',
#      'train',
#      'atm']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 7,
#     'category_type_cb': 1,
#     'locality': 'praha-smichov-ostrovskeho'},
#    'exclusively_at_rk': 1,
#    'category': 1,
#    'has_floor_plan': 0,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/3828229452',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/3828229452',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False},
#     'company': {'url': 'Realitni-expert-Ing-Lucie-Mekhail-Lany',
#      'id': 43446,
#      'name': 'Realitní expert Ing. Lucie Mekhail',
#      'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gW_g/FIgBLy.png?fl=res,140,140,3,ffffff'}},
#    'paid_logo': 1,
#    'locality': 'Praha 5 - Smíchov',
#    'has_video': False,
#    'advert_images_count': 15,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 3828229452,
#    'attractive_offer': 0,
#    'price': 6363000,
#    'price_czk': {'value_raw': 6363000, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/noLBIu.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/noLBIu.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/-10?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/3828229452'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/noLBIu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/H2GBIU.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ls/HiSCJE.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/l0EBIv.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LM/0FbCIi.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_z/RoeBJc.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/noLBIu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 3+1\xa049\xa0m²',
#    'region_tip': 0,
#    'gps': {'lat': 50.06300162336297, 'lon': 14.40556537663703},
#    'has_matterport_url': False},
#   {'labelsReleased': [['after_reconstruction', 'furnished'], ['shop']],
#    'has_panorama': 0,
#    'labels': ['Po rekonstrukci', 'Vybavený', 'Obchod 5 min. pěšky'],
#    'is_auction': False,
#    'labelsAll': [['personal',
#      'after_reconstruction',
#      'brick',
#      'elevator',
#      'furnished'],
#     ['tavern',
#      'candy_shop',
#      'theater',
#      'small_shop',
#      'vet',
#      'movies',
#      'playground',
#      'natural_attraction',
#      'sightseeing',
#      'restaurant',
#      'medic',
#      'kindergarten',
#      'metro',
#      'post_office',
#      'bus_public_transport',
#      'shop',
#      'school',
#      'train',
#      'drugstore',
#      'tram',
#      'atm',
#      'sports']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 7,
#     'category_type_cb': 1,
#     'locality': 'praha-stare-mesto-'},
#    'exclusively_at_rk': 0,
#    'category': 1,
#    'has_floor_plan': 1,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/4188198220',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/4188198220',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False},
#     'company': {'url': 'REFA-Group-s-r-o-Praha-Zizkov',
#      'id': 15138,
#      'name': 'REFA Group s.r.o.',
#      'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gT_u/9gnCrW.png?fl=res,140,140,3,ffffff'}},
#    'paid_logo': 1,
#    'locality': 'Praha 1 - Staré Město',
#    'has_video': False,
#    'advert_images_count': 13,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 4188198220,
#    'attractive_offer': 0,
#    'price': 11103000,
#    'price_czk': {'value_raw': 11103000, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/34BB129.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/34BB129.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/-9?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/4188198220'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/34BB129.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LH/Wb4B1mK.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jt/gNPB1uF.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/VnxB13A.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_K7/k5YB1sk.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_K7/FFCB1sl.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/34BB129.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 3+1\xa049\xa0m²',
#    'region_tip': 0,
#    'gps': {'lat': 50.07889362336297, 'lon': 14.42329237663703},
#    'has_matterport_url': False},
#   {'labelsReleased': [['balcony', 'partly_furnished'], []],
#    'has_panorama': 0,
#    'labels': ['Balkon', 'Částečně vybavený'],
#    'is_auction': False,
#    'labelsAll': [['new_building',
#      'personal',
#      'balcony',
#      'brick',
#      'elevator',
#      'garage',
#      'partly_furnished'],
#     ['small_shop',
#      'tavern',
#      'candy_shop',
#      'vet',
#      'movies',
#      'theater',
#      'playground',
#      'natural_attraction',
#      'metro',
#      'medic',
#      'tram',
#      'shop',
#      'bus_public_transport',
#      'sports',
#      'atm',
#      'post_office',
#      'train',
#      'school',
#      'kindergarten',
#      'drugstore',
#      'restaurant']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 4,
#     'category_type_cb': 1,
#     'locality': 'praha-hostivar-rychtare-petrika'},
#    'exclusively_at_rk': 1,
#    'category': 1,
#    'has_floor_plan': 1,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/1581876556',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/1581876556',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False},
#     'company': {'url': 'GEPARD-REALITY-Pallas-Athena-Praha-Karlin',
#      'id': 27595,
#      'name': 'GEPARD REALITY/Pallas Athena',
#      'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gS_q/LZWGxb.png?fl=res,140,140,3,ffffff'}},
#    'paid_logo': 1,
#    'locality': 'Praha 10 - Hostivař',
#    'has_video': True,
#    'advert_images_count': 20,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 1581876556,
#    'attractive_offer': 0,
#    'price': 3740000,
#    'price_czk': {'value_raw': 3740000, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/2VbYCa.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/2VbYCa.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/-8?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/1581876556'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/2VbYCa.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jn/BVSX2J.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Lp/aJhYHc.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J9/90KX6J.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J9/GerX6K.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Js/8L3YCu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KD/2VbYCa.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 2+kk 25\xa0m²',
#    'region_tip': 0,
#    'gps': {'lat': 50.05015062336297, 'lon': 14.53087937663703},
#    'has_matterport_url': False},
#   {'labelsReleased': [['balcony'], []],
#    'has_panorama': 0,
#    'labels': ['Balkon'],
#    'is_auction': False,
#    'labelsAll': [['personal', 'balcony', 'brick', 'cellar'],
#     ['small_shop',
#      'vet',
#      'candy_shop',
#      'theater',
#      'tavern',
#      'movies',
#      'playground',
#      'sightseeing',
#      'atm',
#      'metro',
#      'drugstore',
#      'sports',
#      'shop',
#      'restaurant',
#      'bus_public_transport',
#      'kindergarten',
#      'medic',
#      'post_office',
#      'train',
#      'tram',
#      'school']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 6,
#     'category_type_cb': 1,
#     'locality': 'praha-nusle-zateckych'},
#    'exclusively_at_rk': 1,
#    'category': 1,
#    'has_floor_plan': 1,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/1206252876',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/1206252876',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False}},
#    'paid_logo': 0,
#    'locality': 'Praha 4 - Nusle',
#    'has_video': False,
#    'advert_images_count': 30,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 1206252876,
#    'attractive_offer': 0,
#    'price': 5520000,
#    'price_czk': {'value_raw': 5520000, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/MMqz0r.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/MMqz0r.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/-7?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/1206252876'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/MMqz0r.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/kyGatG.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/Z5enj5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/xRFHNM.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_0/CcVHPW.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/zk6nj4.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/MMqz0r.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 3+kk 41\xa0m²',
#    'region_tip': 0,
#    'gps': {'lat': 50.05491462336297, 'lon': 14.43956137663703},
#    'has_matterport_url': False},
#   {'labelsReleased': [['balcony'], []],
#    'has_panorama': 0,
#    'labels': ['Balkon'],
#    'is_auction': False,
#    'labelsAll': [['personal',
#      'balcony',
#      'elevator',
#      'garage',
#      'not_furnished'],
#     ['small_shop',
#      'theater',
#      'candy_shop',
#      'vet',
#      'tavern',
#      'movies',
#      'sightseeing',
#      'playground',
#      'shop',
#      'medic',
#      'bus_public_transport',
#      'tram',
#      'sports',
#      'atm',
#      'post_office',
#      'metro',
#      'drugstore',
#      'school',
#      'train',
#      'restaurant',
#      'kindergarten']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 4,
#     'category_type_cb': 1,
#     'locality': 'praha-holesovice-jatecni'},
#    'exclusively_at_rk': 0,
#    'category': 1,
#    'has_floor_plan': 1,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/4054193484',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/4054193484',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False},
#     'company': {'url': 'CREDITAS-Real-Estate-Praha-Jinonice',
#      'id': 27848,
#      'name': 'CREDITAS Real Estate',
#      'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_s/whOD0n.png?fl=res,140,140,3,ffffff'}},
#    'paid_logo': 1,
#    'locality': 'Praha 7 - Holešovice',
#    'has_video': False,
#    'advert_images_count': 7,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 4054193484,
#    'attractive_offer': 0,
#    'price': 4962000,
#    'price_czk': {'value_raw': 4962000, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/HrrYmi.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/HrrYmi.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/-6?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/4054193484'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/HrrYmi.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/T0zYrT.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/fzlT1c.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ls/fPDszf.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/E2fYrU.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_z/TqiYxW.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/HrrYmi.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 2+kk 26\xa0m²',
#    'region_tip': 0,
#    'gps': {'lat': 50.09511062336297, 'lon': 14.45431837663703},
#    'has_matterport_url': False},
#   {'labelsReleased': [[], []],
#    'has_panorama': 0,
#    'labels': [],
#    'is_auction': False,
#    'labelsAll': [['personal', 'elevator', 'garage', 'not_furnished'],
#     ['small_shop',
#      'theater',
#      'vet',
#      'candy_shop',
#      'tavern',
#      'movies',
#      'sightseeing',
#      'playground',
#      'restaurant',
#      'school',
#      'metro',
#      'drugstore',
#      'train',
#      'tram',
#      'kindergarten',
#      'atm',
#      'bus_public_transport',
#      'sports',
#      'medic',
#      'post_office',
#      'shop']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 2,
#     'category_type_cb': 1,
#     'locality': 'praha-holesovice-jatecni'},
#    'exclusively_at_rk': 0,
#    'category': 1,
#    'has_floor_plan': 1,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/2544244044',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/2544244044',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False},
#     'company': {'url': 'CREDITAS-Real-Estate-Praha-Jinonice',
#      'id': 27848,
#      'name': 'CREDITAS Real Estate',
#      'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_s/whOD0n.png?fl=res,140,140,3,ffffff'}},
#    'paid_logo': 1,
#    'locality': 'Praha 7 - Holešovice',
#    'has_video': False,
#    'advert_images_count': 7,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 2544244044,
#    'attractive_offer': 0,
#    'price': 3176000,
#    'price_czk': {'value_raw': 3176000, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/n2dgph.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/n2dgph.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/-5?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/2544244044'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/n2dgph.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/YffYrI.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/lbkYrJ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MN/zV5s2f.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MN/ak3s2g.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_0/yX3Ecu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/n2dgph.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 1+kk 15\xa0m²',
#    'region_tip': 0,
#    'gps': {'lat': 50.09511062336297, 'lon': 14.45431837663703},
#    'has_matterport_url': False},
#   {'labelsReleased': [['loggia'], []],
#    'has_panorama': 0,
#    'labels': ['Lodžie'],
#    'is_auction': False,
#    'labelsAll': [['personal', 'loggia', 'elevator', 'garage', 'not_furnished'],
#     ['small_shop',
#      'theater',
#      'vet',
#      'candy_shop',
#      'tavern',
#      'movies',
#      'sightseeing',
#      'playground',
#      'restaurant',
#      'post_office',
#      'sports',
#      'kindergarten',
#      'medic',
#      'drugstore',
#      'train',
#      'tram',
#      'bus_public_transport',
#      'metro',
#      'atm',
#      'shop',
#      'school']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 6,
#     'category_type_cb': 1,
#     'locality': 'praha-holesovice-jatecni'},
#    'exclusively_at_rk': 0,
#    'category': 1,
#    'has_floor_plan': 1,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/2882934092',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/2882934092',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False},
#     'company': {'url': 'CREDITAS-Real-Estate-Praha-Jinonice',
#      'id': 27848,
#      'name': 'CREDITAS Real Estate',
#      'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_s/whOD0n.png?fl=res,140,140,3,ffffff'}},
#    'paid_logo': 1,
#    'locality': 'Praha 7 - Holešovice',
#    'has_video': False,
#    'advert_images_count': 7,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 2882934092,
#    'attractive_offer': 0,
#    'price': 6135000,
#    'price_czk': {'value_raw': 6135000, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/Hkisuf.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/Hkisuf.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/-4?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/2882934092'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/Hkisuf.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/3kTYrK.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_z/mqgYxO.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/1estA3.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/vYJsug.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/mDRYsx.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/Hkisuf.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 3+kk 37\xa0m²',
#    'region_tip': 0,
#    'gps': {'lat': 50.09511062336297, 'lon': 14.45431837663703},
#    'has_matterport_url': False},
#   {'labelsReleased': [[], []],
#    'has_panorama': 0,
#    'labels': [],
#    'is_auction': False,
#    'labelsAll': [['new_building',
#      'personal',
#      'brick',
#      'elevator',
#      'garage',
#      'not_furnished'],
#     ['candy_shop',
#      'tavern',
#      'small_shop',
#      'theater',
#      'movies',
#      'vet',
#      'playground',
#      'natural_attraction',
#      'sightseeing',
#      'tram',
#      'atm',
#      'bus_public_transport',
#      'shop',
#      'drugstore',
#      'metro',
#      'train',
#      'school',
#      'sports',
#      'medic',
#      'kindergarten',
#      'restaurant',
#      'post_office']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 4,
#     'category_type_cb': 1,
#     'locality': 'praha-jinonice-reporyjska'},
#    'exclusively_at_rk': 0,
#    'category': 1,
#    'has_floor_plan': 0,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/487134540',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/487134540',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False},
#     'company': {'url': 'CREDITAS-Real-Estate-Praha-Jinonice',
#      'id': 27848,
#      'name': 'CREDITAS Real Estate',
#      'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_s/whOD0n.png?fl=res,140,140,3,ffffff'}},
#    'paid_logo': 1,
#    'locality': 'Praha 5 - Jinonice',
#    'has_video': False,
#    'advert_images_count': 16,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 487134540,
#    'attractive_offer': 0,
#    'price': 6567000,
#    'price_czk': {'value_raw': 6567000, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jq/IpxWTn.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jq/IpxWTn.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/-3?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/487134540'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jq/IpxWTn.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/d59WXc.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/J9hMv6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_2/WdLMsH.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/n29I8B.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/JkfWbh.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jq/IpxWTn.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 2+kk 48\xa0m²',
#    'region_tip': 0,
#    'gps': {'lat': 50.04587062336297, 'lon': 14.36083637663703},
#    'has_matterport_url': False},
#   {'labelsReleased': [[], []],
#    'has_panorama': 0,
#    'labels': [],
#    'is_auction': False,
#    'labelsAll': [['new_building',
#      'personal',
#      'brick',
#      'garage',
#      'not_furnished'],
#     ['candy_shop',
#      'tavern',
#      'small_shop',
#      'theater',
#      'movies',
#      'playground',
#      'vet',
#      'natural_attraction',
#      'sightseeing',
#      'post_office',
#      'sports',
#      'atm',
#      'train',
#      'shop',
#      'medic',
#      'tram',
#      'restaurant',
#      'bus_public_transport',
#      'drugstore',
#      'school',
#      'kindergarten',
#      'metro']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 6,
#     'category_type_cb': 1,
#     'locality': 'praha-jinonice-reporyjska'},
#    'exclusively_at_rk': 0,
#    'category': 1,
#    'has_floor_plan': 0,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/1379472716',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/1379472716',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False},
#     'company': {'url': 'CREDITAS-Real-Estate-Praha-Jinonice',
#      'id': 27848,
#      'name': 'CREDITAS Real Estate',
#      'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_s/whOD0n.png?fl=res,140,140,3,ffffff'}},
#    'paid_logo': 1,
#    'locality': 'Praha 5 - Jinonice',
#    'has_video': False,
#    'advert_images_count': 14,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 1379472716,
#    'attractive_offer': 0,
#    'price': 8084000,
#    'price_czk': {'value_raw': 8084000, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/14mKRt.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/14mKRt.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/-2?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/1379472716'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/14mKRt.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jq/kKBWN9.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/uftMsC.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gQ_0/PQnMnK.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/u6fKRu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jw/wMBWQ6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/14mKRt.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 3+kk 60\xa0m²',
#    'region_tip': 0,
#    'gps': {'lat': 50.04587062336297, 'lon': 14.36083637663703},
#    'has_matterport_url': False},
#   {'labelsReleased': [[], []],
#    'has_panorama': 0,
#    'labels': [],
#    'is_auction': False,
#    'labelsAll': [['new_building',
#      'personal',
#      'brick',
#      'garage',
#      'not_furnished'],
#     ['candy_shop',
#      'tavern',
#      'small_shop',
#      'theater',
#      'movies',
#      'playground',
#      'vet',
#      'natural_attraction',
#      'sightseeing',
#      'drugstore',
#      'shop',
#      'sports',
#      'atm',
#      'school',
#      'kindergarten',
#      'medic',
#      'train',
#      'bus_public_transport',
#      'tram',
#      'restaurant',
#      'metro',
#      'post_office']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 4,
#     'category_type_cb': 1,
#     'locality': 'praha-jinonice-reporyjska'},
#    'exclusively_at_rk': 0,
#    'category': 1,
#    'has_floor_plan': 0,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/2604209484',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/2604209484',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False},
#     'company': {'url': 'CREDITAS-Real-Estate-Praha-Jinonice',
#      'id': 27848,
#      'name': 'CREDITAS Real Estate',
#      'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_s/whOD0n.png?fl=res,140,140,3,ffffff'}},
#    'paid_logo': 1,
#    'locality': 'Praha 5 - Jinonice',
#    'has_video': False,
#    'advert_images_count': 13,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 2604209484,
#    'attractive_offer': 0,
#    'price': 5051000,
#    'price_czk': {'value_raw': 5051000, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/C1BI3h.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/C1BI3h.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/-1?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/2604209484'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/C1BI3h.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/32qWeZ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_0/8GNMsy.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_z/eXAMwq.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/o4eWdL.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/e5wWW9.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/C1BI3h.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 2+kk 36\xa0m²',
#    'region_tip': 0,
#    'gps': {'lat': 50.04587062336297, 'lon': 14.36083637663703},
#    'has_matterport_url': False},
#   {'labelsReleased': [[], []],
#    'has_panorama': 0,
#    'labels': [],
#    'is_auction': False,
#    'labelsAll': [['new_building',
#      'personal',
#      'brick',
#      'garage',
#      'not_furnished'],
#     ['candy_shop',
#      'tavern',
#      'small_shop',
#      'theater',
#      'movies',
#      'vet',
#      'playground',
#      'natural_attraction',
#      'sightseeing',
#      'train',
#      'medic',
#      'school',
#      'post_office',
#      'sports',
#      'tram',
#      'drugstore',
#      'kindergarten',
#      'shop',
#      'bus_public_transport',
#      'metro',
#      'restaurant',
#      'atm']],
#    'seo': {'category_main_cb': 1,
#     'category_sub_cb': 6,
#     'category_type_cb': 1,
#     'locality': 'praha-jinonice-reporyjska'},
#    'exclusively_at_rk': 0,
#    'category': 1,
#    'has_floor_plan': 1,
#    '_embedded': {'favourite': {'is_favourite': False,
#      '_links': {'self': {'profile': '/favourite/doc',
#        'href': '/cs/v2/favourite/2704872780',
#        'title': 'Oblibene inzeraty'}}},
#     'note': {'note': '',
#      '_links': {'self': {'profile': '/note/doc',
#        'href': '/cs/v2/note/2704872780',
#        'title': 'Poznamky inzeratu'}},
#      'has_note': False},
#     'company': {'url': 'CREDITAS-Real-Estate-Praha-Jinonice',
#      'id': 27848,
#      'name': 'CREDITAS Real Estate',
#      'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_s/whOD0n.png?fl=res,140,140,3,ffffff'}},
#    'paid_logo': 1,
#    'locality': 'Praha 5 - Jinonice',
#    'has_video': False,
#    'advert_images_count': 15,
#    'new': False,
#    'auctionPrice': 0.0,
#    'type': 1,
#    'hash_id': 2704872780,
#    'attractive_offer': 0,
#    'price': 7326000,
#    'price_czk': {'value_raw': 7326000, 'unit': '', 'name': 'Celková cena'},
#    '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/FTOI2A.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#     'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/FTOI2A.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#     'iterator': {'href': '/cs/v2/estate-iterator/0?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#     'self': {'href': '/cs/v2/estates/2704872780'},
#     'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/FTOI2A.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_z/0WGMxe.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gQ_0/W18Mmq.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/RhhWbd.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/JlPWVX.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#      {'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/DM0MsM.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#     'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/FTOI2A.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#    'rus': False,
#    'name': 'Prodej bytu 3+kk 51\xa0m²',
#    'region_tip': 0,
#    'gps': {'lat': 50.04587062336297, 'lon': 14.36083637663703},
#    'has_matterport_url': False}],
#  'is_saved': {'email_notification': False,
#   'notification_advert_count': 0,
#   'stack_id': 0,
#   'push_notification': False,
#   '_links': {'self': {'href': '/cs/v2/stacks'}},
#   'removed': False,
#   'saved': False},
#  'not_precise_location_count': {'result_size_auction': 0,
#   'result_size': 1162,
#   '_links': {'self': {'profile': '/estates/count/doc',
#     'href': '/cs/v2/estates/count?category_main_cb=1&locality_region_id=10&category_type_cb=3',
#     'title': 'Estate count'}}}}

# %% [markdown]
# ### 1b. Create a function converting sreality json data into pandas dataframe

# %%
def convert_sreality_data_to_df(sreality_data):
    return pd.DataFrame(sreality_data['_embedded']['estates'])

raw = convert_sreality_data_to_df(d)

# %%
raw.head()
# Out:
#                                  labelsReleased  has_panorama  \
# 0                          [[parking_lots], []]             0
# 1                             [[furnished], []]             0
# 2                  [[after_reconstruction], []]             0
# 3  [[in_construction, collective, balcony], []]             0
# 4             [[terrace, partly_furnished], []]             0
#
#                               labels  is_auction  \
# 0                        [Parkování]       False
# 1                         [Vybavený]       False
# 2                  [Po rekonstrukci]       False
# 3  [Ve výstavbě, Družstevní, Balkon]       False
# 4        [Terasa, Částečně vybavený]       False
#
#                                            labelsAll  \
# 0  [[personal, brick, cellar, parking_lots], [tav...
# 1  [[personal, brick, cellar, elevator, furnished...
# 2  [[personal, after_reconstruction, brick, cella...
# 3  [[in_construction, collective, balcony, brick,...
# 4  [[personal, terrace, brick, elevator, partly_f...
#
#                                                  seo  exclusively_at_rk  \
# 0  {'category_main_cb': 1, 'category_sub_cb': 8, ...                  0
# 1  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 2  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 3  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 4  {'category_main_cb': 1, 'category_sub_cb': 5, ...                  0
#
#    category  has_floor_plan  \
# 0         1               1
# 1         1               0
# 2         1               1
# 3         1               1
# 4         1               0
#
#                                            _embedded  ...     hash_id  \
# 0  {'favourite': {'is_favourite': False, '_links'...  ...   662340940
# 1  {'favourite': {'is_favourite': False, '_links'...  ...  3079939148
# 2  {'favourite': {'is_favourite': False, '_links'...  ...  1289888844
# 3  {'favourite': {'is_favourite': False, '_links'...  ...   290006348
# 4  {'favourite': {'is_favourite': False, '_links'...  ...  2725778764
#
#   attractive_offer    price  \
# 0                0        0
# 1                0  5526000
# 2                0  7229000
# 3                0        0
# 4                0  7536000
#
#                                            price_czk  \
# 0  {'value_raw': 0, 'unit': '', 'name': 'Celková ...
# 1  {'value_raw': 5526000, 'unit': '', 'name': 'Ce...
# 2  {'value_raw': 7229000, 'unit': '', 'name': 'Ce...
# 3  {'value_raw': 0, 'unit': '', 'name': 'Celková ...
# 4  {'value_raw': 7536000, 'unit': '', 'name': 'Ce...
#
#                                               _links    rus  \
# 0  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                      name  region_tip  \
# 0  Prodej bytu 4+kk 55 m²     2839154
# 1  Prodej bytu 2+kk 30 m²           0
# 2  Prodej bytu 3+kk 38 m²           0
# 3  Prodej bytu 2+kk 29 m²           0
# 4   Prodej bytu 2+1 32 m²           0
#
#                                                  gps  has_matterport_url
# 0  {'lat': 50.05896962336297, 'lon': 14.516374376...               False
# 1  {'lat': 50.073278623362974, 'lon': 14.43000437...               False
# 2  {'lat': 50.07246262336297, 'lon': 14.430002376...               False
# 3  {'lat': 50.11171162336297, 'lon': 14.491121376...               False
# 4  {'lat': 50.073278623362974, 'lon': 14.43000437...               False
#
# [5 rows x 27 columns]

# %%
#return data frame instead of json
def request_sreality(page, category_main_str, category_type_str, locality_region_id=10):
    category_mains = {'flat':1, 'house':2, 'land':3 }
    category_types = {'sell':1,'rent':2}
    template_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb={category_main}&category_type_cb={category_type}&locality_region_id={locality_region_id}&per_page60&page={page}'
    try:
        request_url = template_url.format(
            category_main=category_mains[category_main_str],
            category_type=category_types[category_type_str],
            locality_region_id=locality_region_id,
            page=page
        )
        r = requests.get(request_url)
        df = pd.DataFrame(r.json()['_embedded']['estates'])
        return df
    except Exception as e:
        print(e)
        
d = request_sreality(0, 'flat', 'sell', 10)

# %% [markdown]
# ### 1c. link function `1b` into function `1a`

# %%
df = request_sreality(0, 'flat', 'sell', 10)
df.head()

# %% [markdown]
# ### 1c. Combining multiple requests into single df
#
# * Function should parametrize:
#     * `start_page` and `end_page`
#     * request parameters
# * construct a list of individual request dfs
# * then feed it into `pd.concat` function

# %%
raw.shape
# Out:
# (21, 27)

# %%
request_sreality
# Out:
# <function __main__.request_sreality(page, category_main_str, category_type_str, locality_region_id=10)>

# %%
def request_multiply_sreality(start_page, end_page, category_main_str, category_type_str, locality_region_id=10):
    list_of_dfs = []
    for i in range(start_page, end_page+1):
        list_of_dfs.append(request_sreality(i, 'flat', 'sell', 10))
    return pd.concat(list_of_dfs)

df = request_multiply_sreality(1, 5, 'flat', 'sell',10)
df.shape
# Out:
# (105, 27)

# %%
#easier
def request_multiply_sreality(start_page, end_page, category_main_str, category_type_str, locality_region_id=10):
    list_of_dfs = [request_sreality(i, 'flat', 'sell', 10) for i in range(start_page, end_page+1)]
    return pd.concat(list_of_dfs)

# %%
df
# Out:
#                                   labelsReleased  has_panorama  \
# 0                                [[terrace], []]             0
# 1                             [[collective], []]             0
# 2                              [[furnished], []]             0
# 3                   [[after_reconstruction], []]             0
# 4   [[in_construction, collective, balcony], []]             0
# ..                                           ...           ...
# 16                     [[not_furnished], [shop]]             0
# 17                         [[loggia, panel], []]             0
# 18                          [[parking_lots], []]             0
# 19                                      [[], []]             0
# 20           [[parking_lots], [shop, drugstore]]             0
#
#                                                labels  is_auction  \
# 0                                            [Terasa]       False
# 1                                        [Družstevní]       False
# 2                                          [Vybavený]       False
# 3                                   [Po rekonstrukci]       False
# 4                   [Ve výstavbě, Družstevní, Balkon]       False
# ..                                                ...         ...
# 16                  [Nevybavený, Obchod 3 min. pěšky]       False
# 17                                 [Lodžie, Panelová]       False
# 18                                        [Parkování]       False
# 19                                                 []       False
# 20  [Parkování, Obchod 7 min. pěšky, Lékárna 7 min...       False
#
#                                             labelsAll  \
# 0   [[personal, terrace, elevator, garage], [taver...
# 1   [[collective, brick], [small_shop, candy_shop,...
# 2   [[personal, brick, cellar, elevator, furnished...
# 3   [[personal, after_reconstruction, brick, cella...
# 4   [[in_construction, collective, balcony, brick,...
# ..                                                ...
# 16  [[new_building, personal, balcony, cellar, ele...
# 17  [[personal, loggia, panel, cellar, elevator, p...
# 18  [[new_building, personal, balcony, elevator, p...
# 19  [[new_building, personal, elevator, partly_fur...
# 20  [[new_building, personal, balcony, cellar, ele...
#
#                                                   seo  exclusively_at_rk  \
# 0   {'category_main_cb': 1, 'category_sub_cb': 8, ...                  0
# 1   {'category_main_cb': 1, 'category_sub_cb': 2, ...                  0
# 2   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 3   {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 4   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# ..                                                ...                ...
# 16  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  1
# 17  {'category_main_cb': 1, 'category_sub_cb': 9, ...                  1
# 18  {'category_main_cb': 1, 'category_sub_cb': 8, ...                  1
# 19  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  1
# 20  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  1
#
#     category  has_floor_plan  \
# 0          1               1
# 1          1               0
# 2          1               0
# 3          1               1
# 4          1               1
# ..       ...             ...
# 16         1               1
# 17         1               0
# 18         1               1
# 19         1               1
# 20         1               0
#
#                                             _embedded  ...     hash_id  \
# 0   {'favourite': {'is_favourite': False, '_links'...  ...   599835980
# 1   {'favourite': {'is_favourite': False, '_links'...  ...  2299286604
# 2   {'favourite': {'is_favourite': False, '_links'...  ...  3079939148
# 3   {'favourite': {'is_favourite': False, '_links'...  ...  1289888844
# 4   {'favourite': {'is_favourite': False, '_links'...  ...   290006348
# ..                                                ...  ...         ...
# 16  {'favourite': {'is_favourite': False, '_links'...  ...   879678796
# 17  {'favourite': {'is_favourite': False, '_links'...  ...  1961538636
# 18  {'favourite': {'is_favourite': False, '_links'...  ...  2080568652
# 19  {'favourite': {'is_favourite': False, '_links'...  ...  2108466508
# 20  {'favourite': {'is_favourite': False, '_links'...  ...  2186990924
#
#    attractive_offer     price  \
# 0                 0         0
# 1                 0   4345000
# 2                 0  11470000
# 3                 0  15004000
# 4                 0         0
# ..              ...       ...
# 16                0   6719000
# 17                0   8690000
# 18                0         0
# 19                0   7531000
# 20                0  12397000
#
#                                             price_czk  \
# 0   {'value_raw': 0, 'unit': '', 'name': 'Celková ...
# 1   {'value_raw': 4345000, 'unit': '', 'name': 'Ce...
# 2   {'value_raw': 11470000, 'unit': '', 'name': 'C...
# 3   {'value_raw': 15004000, 'unit': '', 'name': 'C...
# 4   {'value_raw': 0, 'unit': '', 'name': 'Celková ...
# ..                                                ...
# 16  {'value_raw': 6719000, 'unit': '', 'name': 'Ce...
# 17  {'value_raw': 8690000, 'unit': '', 'name': 'Ce...
# 18  {'value_raw': 0, 'unit': '', 'name': 'Celková ...
# 19  {'value_raw': 7531000, 'unit': '', 'name': 'Ce...
# 20  {'value_raw': 12397000, 'unit': '', 'name': 'C...
#
#                                                _links    rus  \
# 0   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# ..                                                ...    ...
# 16  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 17  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 18  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 19  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 20  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                                  name  region_tip  \
# 0   Prodej bytu 4+kk 301 m² (Mezonet)     2839154
# 1              Prodej bytu 1+kk 40 m²           0
# 2              Prodej bytu 2+kk 63 m²           0
# 3              Prodej bytu 3+kk 79 m²           0
# 4              Prodej bytu 2+kk 60 m²           0
# ..                                ...         ...
# 16             Prodej bytu 1+kk 38 m²           0
# 17              Prodej bytu 4+1 96 m²           0
# 18            Prodej bytu 4+kk 183 m²           0
# 19             Prodej bytu 1+kk 46 m²           0
# 20             Prodej bytu 3+kk 85 m²           0
#
#                                                   gps  has_matterport_url
# 0   {'lat': 50.0690671417214, 'lon': 14.4681958582...               False
# 1   {'lat': 50.08106114172139, 'lon': 14.492606858...               False
# 2   {'lat': 50.0672741417214, 'lon': 14.4360088582...               False
# 3   {'lat': 50.0664581417214, 'lon': 14.4360068582...               False
# 4   {'lat': 50.105707141721396, 'lon': 14.49712585...               False
# ..                                                ...                 ...
# 16  {'lat': 50.0921611417214, 'lon': 14.5005038582...               False
# 17  {'lat': 50.046587141721396, 'lon': 14.52990185...               False
# 18  {'lat': 50.08104114172139, 'lon': 14.441161858...               False
# 19  {'lat': 50.08265914172139, 'lon': 14.465022858...               False
# 20  {'lat': 50.0816441417214, 'lon': 14.5158958582...               False
#
# [105 rows x 27 columns]

# %% [markdown]
# ## Task 2: Cleaning data
#
# ### 2a. Filter columns
# * filter only columns: `['locality', 'price', 'name', 'gps','hash_id','exclusively_at_rk']`
# * use `.copy()` to avoid `SettingWithCopyWarning` later

# %%
df_clear = df[['locality', 'price', 'name', 'gps','hash_id','exclusively_at_rk']].copy()
df_clear
# Out:
#                 locality     price                               name  \
# 0       Praha 3 - Žižkov         0  Prodej bytu 4+kk 301 m² (Mezonet)
# 1       Praha 3 - Žižkov   4345000             Prodej bytu 1+kk 40 m²
# 2   Praha 1 - Nové Město  11470000             Prodej bytu 2+kk 63 m²
# 3   Praha 1 - Nové Město  15004000             Prodej bytu 3+kk 79 m²
# 4                Praha 9         0             Prodej bytu 2+kk 60 m²
# ..                   ...       ...                                ...
# 16       Praha 9 - Libeň   6719000             Prodej bytu 1+kk 38 m²
# 17   Praha 10 - Hostivař   8690000              Prodej bytu 4+1 96 m²
# 18  Praha 1 - Nové Město         0            Prodej bytu 4+kk 183 m²
# 19      Praha 8 - Karlín   7531000             Prodej bytu 1+kk 46 m²
# 20   Praha 9 - Hrdlořezy  12397000             Prodej bytu 3+kk 85 m²
#
#                                                   gps     hash_id  \
# 0   {'lat': 50.0690671417214, 'lon': 14.4681958582...   599835980
# 1   {'lat': 50.08106114172139, 'lon': 14.492606858...  2299286604
# 2   {'lat': 50.0672741417214, 'lon': 14.4360088582...  3079939148
# 3   {'lat': 50.0664581417214, 'lon': 14.4360068582...  1289888844
# 4   {'lat': 50.105707141721396, 'lon': 14.49712585...   290006348
# ..                                                ...         ...
# 16  {'lat': 50.0921611417214, 'lon': 14.5005038582...   879678796
# 17  {'lat': 50.046587141721396, 'lon': 14.52990185...  1961538636
# 18  {'lat': 50.08104114172139, 'lon': 14.441161858...  2080568652
# 19  {'lat': 50.08265914172139, 'lon': 14.465022858...  2108466508
# 20  {'lat': 50.0816441417214, 'lon': 14.5158958582...  2186990924
#
#     exclusively_at_rk
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   1
# ..                ...
# 16                  1
# 17                  1
# 18                  1
# 19                  1
# 20                  1
#
# [105 rows x 6 columns]

# %% [markdown]
# ### 2b: GPS
# * Convert dictionary in `gps` column into two columns - `lat` and `lon`
# * use apply function on gps column
# * Note apply can return multiple columns

# %%
df_clear[['lat', 'lon']] = df_clear['gps'].apply(lambda x: pd.Series(x))
df_clear.head()
# Out:
#                locality     price                               name  \
# 0      Praha 3 - Žižkov         0  Prodej bytu 4+kk 301 m² (Mezonet)
# 1      Praha 3 - Žižkov   4345000             Prodej bytu 1+kk 40 m²
# 2  Praha 1 - Nové Město  11470000             Prodej bytu 2+kk 63 m²
# 3  Praha 1 - Nové Město  15004000             Prodej bytu 3+kk 79 m²
# 4               Praha 9         0             Prodej bytu 2+kk 60 m²
#
#                                                  gps     hash_id  \
# 0  {'lat': 50.0690671417214, 'lon': 14.4681958582...   599835980
# 1  {'lat': 50.08106114172139, 'lon': 14.492606858...  2299286604
# 2  {'lat': 50.0672741417214, 'lon': 14.4360088582...  3079939148
# 3  {'lat': 50.0664581417214, 'lon': 14.4360068582...  1289888844
# 4  {'lat': 50.105707141721396, 'lon': 14.49712585...   290006348
#
#    exclusively_at_rk        lat        lon
# 0                  0  50.069067  14.468196
# 1                  0  50.081061  14.492607
# 2                  0  50.067274  14.436009
# 3                  0  50.066458  14.436007
# 4                  1  50.105707  14.497126

# %% [markdown]
# ### 2b. Get flat type from name
# * Name is always represented by string `Prodej bytu [type of flat] [Area] m^2`
# * try picking third word in string
# * check meaningfulness using `.value_counts()`

# %%
types = df_clear['name'].apply(lambda x: x.split()[2])
types.value_counts()
df_clear['type'] = types

# %% [markdown]
# ### 2c. Get area from name
# * Naive: select the word before last word
# * Then try navigating using the index of `'m²'`
# * if this also fail, then you will need to use regex

# %%
a = 'dfsdfsdfsdf d fdsdsfff mm'
a.find("mm")
# Out:
# 23

# %%
df_clear['area1'] = df_clear['name'].apply(lambda x: x.split()[3])

# %%
def naive_meth(row):
    return row.split()[3]
df_clear['area1'] = df_clear['name'].apply(naive_meth)

# %%
df_clear['area2'] = df_clear['name'].apply(lambda x: x.split()[x.split().index('m²')-1])
df_clear.head()
# Out:
#                locality     price                               name  \
# 0      Praha 3 - Žižkov         0  Prodej bytu 4+kk 301 m² (Mezonet)
# 1      Praha 3 - Žižkov   4345000             Prodej bytu 1+kk 40 m²
# 2  Praha 1 - Nové Město  11470000             Prodej bytu 2+kk 63 m²
# 3  Praha 1 - Nové Město  15004000             Prodej bytu 3+kk 79 m²
# 4               Praha 9         0             Prodej bytu 2+kk 60 m²
#
#                                                  gps     hash_id  \
# 0  {'lat': 50.0690671417214, 'lon': 14.4681958582...   599835980
# 1  {'lat': 50.08106114172139, 'lon': 14.492606858...  2299286604
# 2  {'lat': 50.0672741417214, 'lon': 14.4360088582...  3079939148
# 3  {'lat': 50.0664581417214, 'lon': 14.4360068582...  1289888844
# 4  {'lat': 50.105707141721396, 'lon': 14.49712585...   290006348
#
#    exclusively_at_rk        lat        lon  type area1 area2
# 0                  0  50.069067  14.468196  4+kk   301   301
# 1                  0  50.081061  14.492607  1+kk    40    40
# 2                  0  50.067274  14.436009  2+kk    63    63
# 3                  0  50.066458  14.436007  3+kk    79    79
# 4                  1  50.105707  14.497126  2+kk    60    60

# %%
def name_to_area(nm):
    return nm.split()[nm.split().index('m²')-1]

df_clear['area_3'] = df_clear.apply(name_to_area)
df_clear.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5748\428705956.py in ?()
#       1 def name_to_area(nm):
#       2     return nm.split()[nm.split().index('m²')-1]
#       3
# ----> 4 df_clear['area_3'] = df_clear.apply(name_to_area)
#       5 df_clear.head()
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py in ?(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10357             engine_kwargs=engine_kwargs,
#   10358             args=args,
#   10359             kwargs=kwargs,
#   10360         )
# > 10361         return op.apply().__finalize__(self, method="apply")
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\apply.py in ?(self)
#     912         # raw
#     913         elif self.raw:
#     914             return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
#     915
# --> 916         return self.apply_standard()
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\apply.py in ?(self)
#    1061     def apply_standard(self):
#    1062         if self.engine == "python":
# -> 1063             results, res_index = self.apply_series_generator()
#    1064         else:
#    1065             results, res_index = self.apply_series_numba()
#    1066
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\apply.py in ?(self)
#    1077
#    1078         with option_context("mode.chained_assignment", None):
#    1079             for i, v in enumerate(series_gen):
#    1080                 # ignore SettingWithCopy here in case the user mutates
# -> 1081                 results[i] = self.func(v, *self.args, **self.kwargs)
#    1082                 if isinstance(results[i], ABCSeries):
#    1083                     # If we have a view on v, we need to make a copy because
#    1084                     #  series_generator will swap out the underlying data
#
# ~\AppData\Local\Temp\ipykernel_5748\428705956.py in ?(nm)
#       1 def name_to_area(nm):
# ----> 2     return nm.split()[nm.split().index('m²')-1]
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
df_clear
# Out:
#                 locality     price                               name  \
# 0       Praha 3 - Žižkov         0  Prodej bytu 4+kk 301 m² (Mezonet)
# 1       Praha 3 - Žižkov   4345000             Prodej bytu 1+kk 40 m²
# 2   Praha 1 - Nové Město  11470000             Prodej bytu 2+kk 63 m²
# 3   Praha 1 - Nové Město  15004000             Prodej bytu 3+kk 79 m²
# 4                Praha 9         0             Prodej bytu 2+kk 60 m²
# ..                   ...       ...                                ...
# 16       Praha 9 - Libeň   6719000             Prodej bytu 1+kk 38 m²
# 17   Praha 10 - Hostivař   8690000              Prodej bytu 4+1 96 m²
# 18  Praha 1 - Nové Město         0            Prodej bytu 4+kk 183 m²
# 19      Praha 8 - Karlín   7531000             Prodej bytu 1+kk 46 m²
# 20   Praha 9 - Hrdlořezy  12397000             Prodej bytu 3+kk 85 m²
#
#                                                   gps     hash_id  \
# 0   {'lat': 50.0690671417214, 'lon': 14.4681958582...   599835980
# 1   {'lat': 50.08106114172139, 'lon': 14.492606858...  2299286604
# 2   {'lat': 50.0672741417214, 'lon': 14.4360088582...  3079939148
# 3   {'lat': 50.0664581417214, 'lon': 14.4360068582...  1289888844
# 4   {'lat': 50.105707141721396, 'lon': 14.49712585...   290006348
# ..                                                ...         ...
# 16  {'lat': 50.0921611417214, 'lon': 14.5005038582...   879678796
# 17  {'lat': 50.046587141721396, 'lon': 14.52990185...  1961538636
# 18  {'lat': 50.08104114172139, 'lon': 14.441161858...  2080568652
# 19  {'lat': 50.08265914172139, 'lon': 14.465022858...  2108466508
# 20  {'lat': 50.0816441417214, 'lon': 14.5158958582...  2186990924
#
#     exclusively_at_rk        lat        lon  type area1 area2
# 0                   0  50.069067  14.468196  4+kk   301   301
# 1                   0  50.081061  14.492607  1+kk    40    40
# 2                   0  50.067274  14.436009  2+kk    63    63
# 3                   0  50.066458  14.436007  3+kk    79    79
# 4                   1  50.105707  14.497126  2+kk    60    60
# ..                ...        ...        ...   ...   ...   ...
# 16                  1  50.092161  14.500504  1+kk    38    38
# 17                  1  50.046587  14.529902   4+1    96    96
# 18                  1  50.081041  14.441162  4+kk   183   183
# 19                  1  50.082659  14.465023  1+kk    46    46
# 20                  1  50.081644  14.515896  3+kk    85    85
#
# [105 rows x 11 columns]

# %%
df_clear['area1'] = df_clear['area1'].astype('int')

# %% [markdown]
# ## Bonus: Convert `labelsAll` into categorical variables
#
# ### Task 4a. Get all possible label names
# * deal with nested-list structure
# * Hint: try to sum the whole column
# * Needed to Iterate through all labels in all rows and

# %% [markdown]
# ### 4b. Test existence of label `cellar` for offers
# * again deal with nested list of list structure
# * write generic function `test_existence_of_label(offer_labels,label)`

# %% [markdown]
# ### 4c. Test existence of all possible labels
# * use apply returning series with all labels
