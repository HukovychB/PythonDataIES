# %%
import requests
import pandas as pd
import time

# %% [markdown]
# # Seminar - APIs, DBs and Live coding

# %% [markdown]
# ## Task 1: Requesting API
# ### 1a. Create a function requesting data from sreality
#
#
# ```python
# base_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb=1&category_type_cb=1&locality_region_id=10&per_page60&page={}'.format(i)
#
# r = requests.get(base_url)
# d = r.json()
# ```
#
# * function should parametrize:
#     * `category_main_cb` - `{'flat':1, 'house':2, 'land':3 }`
#     * `category_type_cb` - `{'sell':1,'rent':2}`
#     * `locality_region_id` - use 10 as default value
#     * `page` parameter
# * use string inputs for `category_main_cb` and `category_type_cb`
# * include try/except clause to handle errors
# * function should return JSON data in python types
# * do not forget to sleep each request at least 0.5s

# %%
# %%time
print('Hi')
# Out:
# Hi
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# %%time
time.sleep(5)
# Out:
# CPU times: total: 0 ns
# Wall time: 5 s

# %%
# %%time
time.sleep(1)
# Out:
# CPU times: total: 0 ns
# Wall time: 1 s

# %%
def request_sreality(page, category_main_str, category_type_str, locality_region_id=10):
    time.sleep(0.5)
    category_mains = {'flat':1, 'house':2, 'land':3 }
    category_types = {'sell':1,'rent':2}
    template_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb={category_main}&category_type_cb={category_type}&locality_region_id={locality_region_id}&per_page60&page={page}'
    try:
        request_url = template_url.format(
            category_main=category_mains[category_main_str],
            category_type=category_types[category_type_str],
            locality_region_id=locality_region_id,
            page=page
        )
        r = requests.get(request_url)
        return r.json()
    except Exception as e:
        print(e)
d = request_sreality(0, 'flat', 'sell', 10)

# %%
d.keys()
# Out:
# dict_keys(['meta_description', 'result_size', '_embedded', 'filterLabels', 'title', 'filter', '_links', 'locality', 'locality_dativ', 'logged_in', 'per_page', 'category_instrumental', 'page', 'filterLabels2'])

# %%
d['meta_description']
# Out:
# '4460 realit v nabídce prodej bytů Praha. Vyberte si novou nemovitost na sreality.cz s hledáním na mapě a velkými náhledy fotografií nabízených bytů.'

# %%
d['result_size']
# Out:
# 4460

# %%
d['_embedded'].keys()
# Out:
# dict_keys(['estates', 'is_saved', 'not_precise_location_count'])

# %%
d
# Out:
# {'meta_description': '4460 realit v nabídce prodej bytů Praha. Vyberte si novou nemovitost na sreality.cz s hledáním na mapě a velkými náhledy fotografií nabízených bytů.',
#  'result_size': 4460,
#  '_embedded': {'estates': [{'labelsReleased': [['new_building',
#       'parking_lots',
#       'garage'],
#      []],
#     'has_panorama': 0,
#     'labels': ['Novostavba', 'Parkování', 'Garáž'],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'balcony',
#       'cellar',
#       'elevator',
#       'parking_lots',
#       'garage',
#       'partly_furnished'],
#      ['candy_shop',
#       'small_shop',
#       'theater',
#       'vet',
#       'tavern',
#       'movies',
#       'playground',
#       'sightseeing',
#       'tram',
#       'bus_public_transport',
#       'post_office',
#       'school',
#       'metro',
#       'shop',
#       'atm',
#       'kindergarten',
#       'drugstore',
#       'sports',
#       'medic',
#       'restaurant',
#       'train']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-zizkov-seifertova'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/91751756',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/91751756',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'CTR-Viktoria-Center-Praha-Zizkov',
#       'id': 27177,
#       'name': 'CTR Viktoria Center',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_F_L/KFwI3w.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 3 - Žižkov',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 91751756,
#     'attractive_offer': 0,
#     'price': 10047000,
#     'price_czk': {'value_raw': 10047000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/AwG8gx.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/AwG8gx.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-20?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/91751756?region_tip=2826899'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/AwG8gx.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ls/Sab8Rt.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ls/cay8Ru.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MN/nh08RF.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MN/Rmr8RG.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jx/y8Sg8J.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/AwG8gx.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 81\xa0m²',
#     'region_tip': 2826899,
#     'gps': {'lat': 50.07365718253041, 'lon': 14.456714817469587},
#     'has_matterport_url': False},
#    {'labelsReleased': [['parking_lots'], ['post_office', 'medic']],
#     'has_panorama': 0,
#     'labels': ['Parkování', 'Pošta 6 min. pěšky', 'Lékař 11 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'balcony',
#       'brick',
#       'parking_lots',
#       'furnished'],
#      ['candy_shop',
#       'small_shop',
#       'theater',
#       'tavern',
#       'vet',
#       'movies',
#       'playground',
#       'natural_attraction',
#       'sightseeing',
#       'metro',
#       'school',
#       'kindergarten',
#       'restaurant',
#       'atm',
#       'shop',
#       'sports',
#       'medic',
#       'bus_public_transport',
#       'drugstore',
#       'train',
#       'tram',
#       'post_office']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 5,
#      'category_type_cb': 1,
#      'locality': 'praha-smichov-na-brezince'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1756878156',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1756878156',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Smíchov',
#     'has_video': False,
#     'advert_images_count': 13,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1756878156,
#     'attractive_offer': 0,
#     'price': 10823000,
#     'price_czk': {'value_raw': 10823000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jn/IvZBOck.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jn/IvZBOck.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-19?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1756878156'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jn/IvZBOck.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ko/jzFBOmU.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LH/XfcBOXY.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J9/8VyBOhk.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jn/jtXBOcl.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ko/836BOmV.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jn/IvZBOck.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+1\xa092\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.055205182530415, 'lon': 14.407374817469586},
#     'has_matterport_url': True},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick', 'cellar'],
#      ['theater',
#       'vet',
#       'candy_shop',
#       'small_shop',
#       'tavern',
#       'movies',
#       'playground',
#       'sightseeing',
#       'natural_attraction',
#       'drugstore',
#       'kindergarten',
#       'metro',
#       'post_office',
#       'restaurant',
#       'shop',
#       'school',
#       'medic',
#       'sports',
#       'bus_public_transport',
#       'atm',
#       'tram',
#       'train']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-smichov-u-mrazovky'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3097630028',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3097630028',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Smíchov',
#     'has_video': False,
#     'advert_images_count': 25,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 3097630028,
#     'attractive_offer': 0,
#     'price': 9317000,
#     'price_czk': {'value_raw': 9317000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/gJRvbQ.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/gJRvbQ.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-18?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/3097630028'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/gJRvbQ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/3Sd9Vw.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/OCw9IF.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/5Ihj9G.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/69C9Vx.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/PEzvbR.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/gJRvbQ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 67\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.05478218253042, 'lon': 14.400988817469587},
#     'has_matterport_url': False},
#    {'labelsReleased': [['panel'], ['shop']],
#     'has_panorama': 0,
#     'labels': ['Panelová', 'Obchod 7 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'panel', 'cellar', 'elevator'],
#      ['vet',
#       'small_shop',
#       'theater',
#       'candy_shop',
#       'tavern',
#       'movies',
#       'playground',
#       'natural_attraction',
#       'medic',
#       'drugstore',
#       'bus_public_transport',
#       'metro',
#       'restaurant',
#       'kindergarten',
#       'train',
#       'sports',
#       'atm',
#       'school',
#       'post_office',
#       'tram',
#       'shop']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 7,
#      'category_type_cb': 1,
#      'locality': 'praha-liben-bedrichovska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/506537292',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/506537292',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Duna-House-Praha-Michle',
#       'id': 43314,
#       'name': 'Duna House',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QJ_g/AKtCu.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 8 - Libeň',
#     'has_video': False,
#     'advert_images_count': 22,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 506537292,
#     'attractive_offer': 0,
#     'price': 8537000,
#     'price_czk': {'value_raw': 8537000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/AZN4FJ.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/AZN4FJ.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-17?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/506537292'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/AZN4FJ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/rqB3ud.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MN/KNY3z9.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/2cWrqP.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/rvb3td.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/9JEew9.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/AZN4FJ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+1\xa079\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.11638918253041, 'lon': 14.488324817469586},
#     'has_matterport_url': False},
#    {'labelsReleased': [['new_building'], ['metro']],
#     'has_panorama': 0,
#     'labels': ['Novostavba', 'Metro 7 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'balcony',
#       'brick',
#       'elevator',
#       'partly_furnished'],
#      ['small_shop',
#       'tavern',
#       'vet',
#       'candy_shop',
#       'theater',
#       'playground',
#       'natural_attraction',
#       'movies',
#       'atm',
#       'drugstore',
#       'restaurant',
#       'bus_public_transport',
#       'sports',
#       'tram',
#       'shop',
#       'kindergarten',
#       'school',
#       'metro',
#       'medic',
#       'train',
#       'post_office']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 2,
#      'category_type_cb': 1,
#      'locality': 'praha-trebonice-thomasova'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/598561868',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/598561868',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Třebonice',
#     'has_video': False,
#     'advert_images_count': 19,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 598561868,
#     'attractive_offer': 0,
#     'price': 5406000,
#     'price_czk': {'value_raw': 5406000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Kc/5PUejP.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Kc/5PUejP.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-16?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/598561868'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Kc/5PUejP.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Kc/bzGejO.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J5/TXAVk.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MD/voCed4.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Kc/wFDejQ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J5/oxVVi.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Kc/5PUejP.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 1+kk 34\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.03676518253042, 'lon': 14.310620817469585},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], ['train']],
#     'has_panorama': 0,
#     'labels': ['Vlak 4 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick', 'cellar'],
#      ['small_shop',
#       'theater',
#       'candy_shop',
#       'vet',
#       'playground',
#       'movies',
#       'tavern',
#       'natural_attraction',
#       'sightseeing',
#       'school',
#       'restaurant',
#       'train',
#       'drugstore',
#       'shop',
#       'bus_public_transport',
#       'tram',
#       'sports',
#       'kindergarten',
#       'medic',
#       'atm',
#       'metro',
#       'post_office']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 5,
#      'category_type_cb': 1,
#      'locality': 'praha-kosire-v-cibulkach'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/973903180',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/973903180',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Košíře',
#     'has_video': False,
#     'advert_images_count': 19,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 973903180,
#     'attractive_offer': 0,
#     'price': 9198000,
#     'price_czk': {'value_raw': 9198000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jk/x9TBXPD.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jk/x9TBXPD.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-15?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/973903180'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jk/x9TBXPD.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jq/vg3BWmW.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jk/KvnBXOD.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jq/I1iBWma.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jk/J4qBXOF.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jq/NDQBWmY.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jk/x9TBXPD.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+1\xa069\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.05431218253042, 'lon': 14.371471817469587},
#     'has_matterport_url': False},
#    {'labelsReleased': [['after_reconstruction', 'panel'],
#      ['post_office', 'medic']],
#     'has_panorama': 0,
#     'labels': ['Po rekonstrukci',
#      'Panelová',
#      'Pošta 6 min. pěšky',
#      'Lékař 7 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'after_reconstruction',
#       'panel',
#       'cellar',
#       'elevator',
#       'partly_furnished'],
#      ['small_shop',
#       'candy_shop',
#       'tavern',
#       'theater',
#       'vet',
#       'playground',
#       'movies',
#       'sightseeing',
#       'restaurant',
#       'post_office',
#       'school',
#       'drugstore',
#       'atm',
#       'metro',
#       'sports',
#       'bus_public_transport',
#       'medic',
#       'kindergarten',
#       'shop',
#       'tram',
#       'train']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-bohnice-lodzska'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1557132620',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1557132620',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 8 - Bohnice',
#     'has_video': False,
#     'advert_images_count': 13,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1557132620,
#     'attractive_offer': 0,
#     'price': 5307000,
#     'price_czk': {'value_raw': 5307000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J7/yWPB1Qi.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J7/yWPB1Qi.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-14?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1557132620'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J7/yWPB1Qi.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jr/sIXBbbV.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Lm/UJdm4X.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Lm/QYooTo.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J7/miaB1Qj.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LF/kcfB0lg.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J7/yWPB1Qi.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 45\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.119273182530414, 'lon': 14.428792817469587},
#     'has_matterport_url': False},
#    {'labelsReleased': [['collective', 'after_reconstruction'],
#      ['train', 'shop']],
#     'has_panorama': 0,
#     'labels': ['Družstevní',
#      'Po rekonstrukci',
#      'Vlak 5 min. pěšky',
#      'Obchod 6 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['collective',
#       'after_reconstruction',
#       'balcony',
#       'brick',
#       'cellar',
#       'partly_furnished'],
#      ['candy_shop',
#       'small_shop',
#       'tavern',
#       'theater',
#       'vet',
#       'playground',
#       'movies',
#       'sightseeing',
#       'metro',
#       'kindergarten',
#       'train',
#       'atm',
#       'shop',
#       'restaurant',
#       'school',
#       'medic',
#       'sports',
#       'bus_public_transport',
#       'tram',
#       'drugstore',
#       'post_office']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 5,
#      'category_type_cb': 1,
#      'locality': 'praha-bubenec-ve-struhach'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1559098700',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1559098700',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 6 - Bubeneč',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1559098700,
#     'attractive_offer': 0,
#     'price': 8440000,
#     'price_czk': {'value_raw': 8440000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jl/XvaBwxp.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jl/XvaBwxp.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-13?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1559098700'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jl/XvaBwxp.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jr/rMOBlCS.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_K5/BWWB3wy.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MJ/xbxBOu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_K5/59YCEzH.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jr/V2fFvI.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jl/XvaBwxp.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+1\xa058\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.099738182530416, 'lon': 14.407840817469586},
#     'has_matterport_url': False},
#    {'labelsReleased': [['not_furnished'], ['metro']],
#     'has_panorama': 0,
#     'labels': ['Nevybavený', 'Metro 3 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick', 'cellar', 'not_furnished'],
#      ['vet',
#       'theater',
#       'small_shop',
#       'tavern',
#       'candy_shop',
#       'playground',
#       'movies',
#       'sightseeing',
#       'restaurant',
#       'medic',
#       'sports',
#       'metro',
#       'drugstore',
#       'post_office',
#       'train',
#       'kindergarten',
#       'bus_public_transport',
#       'tram',
#       'shop',
#       'atm',
#       'school']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 5,
#      'category_type_cb': 1,
#      'locality': 'praha-hradcany-mickiewiczova'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1673311564',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1673311564',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 6 - Hradčany',
#     'has_video': False,
#     'advert_images_count': 19,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1673311564,
#     'attractive_offer': 0,
#     'price': 8126000,
#     'price_czk': {'value_raw': 8126000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Ji/XMxuQH.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Ji/XMxuQH.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-12?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1673311564'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Ji/XMxuQH.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Lh/GiaBDsA.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_J9/iuNB64r.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_K2/N9KBVbs.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Lh/1amBDr9.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_J6/hZyUrZ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Ji/XMxuQH.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+1\xa071\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.08465818253041, 'lon': 14.417349817469587},
#     'has_matterport_url': False},
#    {'labelsReleased': [['not_furnished'], []],
#     'has_panorama': 0,
#     'labels': ['Nevybavený'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick', 'cellar', 'elevator', 'not_furnished'],
#      ['theater',
#       'small_shop',
#       'vet',
#       'candy_shop',
#       'tavern',
#       'movies',
#       'playground',
#       'sightseeing',
#       'restaurant',
#       'train',
#       'shop',
#       'school',
#       'tram',
#       'post_office',
#       'metro',
#       'drugstore',
#       'medic',
#       'sports',
#       'atm',
#       'kindergarten',
#       'bus_public_transport']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 5,
#      'category_type_cb': 1,
#      'locality': 'praha-nusle-na-veseli'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3820614988',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3820614988',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 4 - Nusle',
#     'has_video': False,
#     'advert_images_count': 15,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 3820614988,
#     'attractive_offer': 0,
#     'price': 8775000,
#     'price_czk': {'value_raw': 8775000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MI/2zqBt0M.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MI/2zqBt0M.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-11?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/3820614988'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MI/2zqBt0M.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KB/JFfByNu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KB/eC2B39g.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LF/ItZBxuh.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Km/0zY7CG.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jr/ayuBYns.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MI/2zqBt0M.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+1\xa083\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.04502418253041, 'lon': 14.452144817469586},
#     'has_matterport_url': False},
#    {'labelsReleased': [['parking_lots'], []],
#     'has_panorama': 0,
#     'labels': ['Parkování'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'brick',
#       'elevator',
#       'parking_lots',
#       'furnished'],
#      ['candy_shop',
#       'small_shop',
#       'tavern',
#       'theater',
#       'vet',
#       'playground',
#       'sightseeing',
#       'movies',
#       'medic',
#       'metro',
#       'restaurant',
#       'school',
#       'bus_public_transport',
#       'sports',
#       'drugstore',
#       'shop',
#       'kindergarten',
#       'train',
#       'post_office',
#       'tram',
#       'atm']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-liben-nad-rokoskou'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/668795980',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/668795980',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Exclusive-Properties-s-r-o-Praha-Liben',
#       'id': 13735,
#       'name': 'Exclusive Properties, s.r.o.',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_G_C/MrYB8JB.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 8 - Libeň',
#     'has_video': True,
#     'advert_images_count': 25,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 668795980,
#     'attractive_offer': 0,
#     'price': 11809000,
#     'price_czk': {'value_raw': 11809000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_0/WCnYla.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_0/WCnYla.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-10?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/668795980'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_0/WCnYla.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_0/GSmEQp.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_z/6wgYiH.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MN/FS1shh.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MN/DgLshi.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/ygwgVH.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_0/WCnYla.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 88\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.10647818253042, 'lon': 14.459090817469587},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick', 'cellar', 'elevator', 'furnished'],
#      ['candy_shop',
#       'small_shop',
#       'vet',
#       'theater',
#       'tavern',
#       'playground',
#       'movies',
#       'natural_attraction',
#       'sightseeing',
#       'school',
#       'restaurant',
#       'post_office',
#       'tram',
#       'bus_public_transport',
#       'drugstore',
#       'sports',
#       'medic',
#       'atm',
#       'metro',
#       'shop',
#       'train',
#       'kindergarten']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-smichov-plzenska'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1416312140',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1416312140',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Smíchov',
#     'has_video': True,
#     'advert_images_count': 12,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1416312140,
#     'attractive_offer': 0,
#     'price': 4604000,
#     'price_czk': {'value_raw': 4604000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/lo7723.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/lo7723.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-9?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1416312140'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/lo7723.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jx/bFmggy.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/hZK724.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jx/14Xggz.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/4vSuMJ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/pMOiuY.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/lo7723.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 40\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.059798182530415, 'lon': 14.388557817469586},
#     'has_matterport_url': False},
#    {'labelsReleased': [['parking_lots'], []],
#     'has_panorama': 0,
#     'labels': ['Parkování'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'brick',
#       'cellar',
#       'elevator',
#       'parking_lots',
#       'partly_furnished'],
#      ['small_shop',
#       'vet',
#       'theater',
#       'candy_shop',
#       'tavern',
#       'playground',
#       'movies',
#       'natural_attraction',
#       'sightseeing',
#       'tram',
#       'sports',
#       'train',
#       'bus_public_transport',
#       'drugstore',
#       'kindergarten',
#       'medic',
#       'post_office',
#       'atm',
#       'restaurant',
#       'metro',
#       'shop',
#       'school']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 8,
#      'category_type_cb': 1,
#      'locality': 'praha-smichov-u-pernikarky'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2607060300',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2607060300',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Smíchov',
#     'has_video': True,
#     'advert_images_count': 30,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2607060300,
#     'attractive_offer': 0,
#     'price': 20044000,
#     'price_czk': {'value_raw': 20044000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MN/dEsg8S.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MN/dEsg8S.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-8?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2607060300'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MN/dEsg8S.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MN/3ahg8T.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/yIcSJT.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gT_4/XiOEMg.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ls/k8pg7P.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/sY5gsS.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MN/dEsg8S.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 4+kk 203\xa0m² (Podkrovní)',
#     'region_tip': 0,
#     'gps': {'lat': 50.06412818253041, 'lon': 14.393855817469586},
#     'has_matterport_url': False},
#    {'labelsReleased': [['after_reconstruction', 'panel', 'not_furnished'], []],
#     'has_panorama': 0,
#     'labels': ['Po rekonstrukci', 'Panelová', 'Nevybavený'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'after_reconstruction',
#       'panel',
#       'not_furnished'],
#      ['vet',
#       'small_shop',
#       'theater',
#       'candy_shop',
#       'tavern',
#       'movies',
#       'playground',
#       'natural_attraction',
#       'school',
#       'metro',
#       'kindergarten',
#       'restaurant',
#       'atm',
#       'medic',
#       'sports',
#       'bus_public_transport',
#       'post_office',
#       'shop',
#       'drugstore',
#       'train',
#       'tram']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-strizkov-decinska'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3584509004',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3584509004',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 8 - Střížkov',
#     'has_video': True,
#     'advert_images_count': 11,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 3584509004,
#     'attractive_offer': 0,
#     'price': 4948000,
#     'price_czk': {'value_raw': 4948000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/tzkaTK.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/tzkaTK.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-7?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/3584509004'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/tzkaTK.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ls/iogxHj.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/VRxjkT.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_0/tE1GI4.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ls/q8IxHk.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/gktaYv.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_0/tzkaTK.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 46\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.11481318253041, 'lon': 14.493778817469586},
#     'has_matterport_url': False},
#    {'labelsReleased': [['new_building', 'collective'], ['metro', 'medic']],
#     'has_panorama': 0,
#     'labels': ['Novostavba',
#      'Družstevní',
#      'Metro 7 min. pěšky',
#      'Lékař 9 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'collective',
#       'brick',
#       'cellar',
#       'elevator',
#       'furnished'],
#      ['small_shop',
#       'theater',
#       'vet',
#       'tavern',
#       'candy_shop',
#       'movies',
#       'playground',
#       'sightseeing',
#       'train',
#       'drugstore',
#       'medic',
#       'kindergarten',
#       'school',
#       'sports',
#       'atm',
#       'restaurant',
#       'post_office',
#       'metro',
#       'bus_public_transport',
#       'tram',
#       'shop']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-holesovice-janovskeho'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/4228154700',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/4228154700',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 7 - Holešovice',
#     'has_video': True,
#     'advert_images_count': 14,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 4228154700,
#     'attractive_offer': 0,
#     'price': 7909000,
#     'price_czk': {'value_raw': 7909000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/jyvVni.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/jyvVni.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-6?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/4228154700'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/jyvVni.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/UUYVlF.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MN/kxsoE0.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/4rmVnj.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/0XvO78.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/vIqoGy.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_0/jyvVni.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 54\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.09033818253042, 'lon': 14.445503817469586},
#     'has_matterport_url': True},
#    {'labelsReleased': [['terrace', 'parking_lots', 'garage'], []],
#     'has_panorama': 0,
#     'labels': ['Terasa', 'Parkování', 'Garáž'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'terrace',
#       'brick',
#       'cellar',
#       'parking_lots',
#       'garage',
#       'furnished'],
#      ['small_shop',
#       'candy_shop',
#       'theater',
#       'tavern',
#       'vet',
#       'movies',
#       'playground',
#       'natural_attraction',
#       'shop',
#       'post_office',
#       'bus_public_transport',
#       'medic',
#       'tram',
#       'restaurant',
#       'drugstore',
#       'atm',
#       'sports',
#       'metro',
#       'train',
#       'kindergarten',
#       'school']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-kyje-federova'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1408906572',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1408906572',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Jan-Vesecky-realitni-makler-Prezletice',
#       'id': 31935,
#       'name': 'Jan Vesecký - realitní makléř',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QN_3/AOpTqv.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 9 - Kyje',
#     'has_video': True,
#     'advert_images_count': 28,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1408906572,
#     'attractive_offer': 0,
#     'price': 10715000,
#     'price_czk': {'value_raw': 10715000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LI/xjrSdT.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LI/xjrSdT.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-5?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
# ...
#      'iterator': {'href': '/cs/v2/estate-iterator/-4?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/822294876'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_KN/gYINd0.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Kd/NOVNic.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_JV/ySFMZf.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_KN/mYsNd1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LQ/HeQQk1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Ja/R5QODj.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_KN/gYINd0.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu atypické 42\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.06718718253041, 'lon': 14.435566817469587},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick'],
#      ['theater',
#       'small_shop',
#       'vet',
#       'candy_shop',
#       'tavern',
#       'movies',
#       'playground',
#       'sightseeing',
#       'train',
#       'school',
#       'metro',
#       'restaurant',
#       'post_office',
#       'drugstore',
#       'tram',
#       'bus_public_transport',
#       'kindergarten',
#       'atm',
#       'sports',
#       'medic',
#       'shop']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-nusle-spoluprace'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2660677980',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2660677980',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Duna-House-Praha-Michle',
#       'id': 43314,
#       'name': 'Duna House',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QJ_g/AKtCu.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 4 - Nusle',
#     'has_video': False,
#     'advert_images_count': 11,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2660677980,
#     'attractive_offer': 0,
#     'price': 6771000,
#     'price_czk': {'value_raw': 6771000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/Wlps9z.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/Wlps9z.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-3?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2660677980'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/Wlps9z.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_KG/DgA63L.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/Gycs91.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/PFIhij.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/2O0ube.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ls/uDy6pp.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/Wlps9z.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 57\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.044116182530416, 'lon': 14.451450817469587},
#     'has_matterport_url': False},
#    {'labelsReleased': [['new_building'], []],
#     'has_panorama': 0,
#     'labels': ['Novostavba'],
#     'is_auction': False,
#     'labelsAll': [['new_building', 'personal', 'balcony', 'brick'],
#      ['small_shop',
#       'tavern',
#       'candy_shop',
#       'vet',
#       'theater',
#       'movies',
#       'playground',
#       'natural_attraction',
#       'medic',
#       'shop',
#       'train',
#       'metro',
#       'restaurant',
#       'tram',
#       'atm',
#       'bus_public_transport',
#       'school',
#       'sports',
#       'drugstore',
#       'kindergarten',
#       'post_office']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-strizkov-zaksinska'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/406324556',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/406324556',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Stach-Reality-Praha-Chodov',
#       'id': 64742,
#       'name': 'Stach Reality',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QO_z/3ucBTo.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 9 - Střížkov',
#     'has_video': True,
#     'advert_images_count': 18,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 406324556,
#     'attractive_offer': 0,
#     'price': 7476000,
#     'price_czk': {'value_raw': 7476000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/yt7vRI.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/yt7vRI.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-2?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/406324556'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/yt7vRI.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/f1D88a.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_MN/pOG85l.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/fGmj0I.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_KC/UuC88b.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_LA/okj8uT.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/yt7vRI.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 63\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.119197182530414, 'lon': 14.505359817469586},
#     'has_matterport_url': False},
#    {'labelsReleased': [['panel'], []],
#     'has_panorama': 0,
#     'labels': ['Panelová'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'balcony',
#       'panel',
#       'cellar',
#       'elevator',
#       'partly_furnished'],
#      ['small_shop',
#       'school',
#       'kindergarten',
#       'restaurant',
#       'candy_shop',
#       'atm',
#       'post_office',
#       'tavern',
#       'shop',
#       'drugstore',
#       'sports',
#       'vet',
#       'medic',
#       'theater',
#       'bus_public_transport',
#       'train',
#       'playground',
#       'movies',
#       'metro',
#       'tram',
#       'natural_attraction']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-hostivar-bruslarska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2159543628',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2159543628',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 10 - Hostivař',
#     'has_video': False,
#     'advert_images_count': 14,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2159543628,
#     'attractive_offer': 0,
#     'price': 7898000,
#     'price_czk': {'value_raw': 7898000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/DjEmYV.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/DjEmYV.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-1?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2159543628'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/DjEmYV.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/7x1BBVC.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/N6fxzU.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/eMqzP5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ls/ImDBBg4.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_Ks/0q3BBVB.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/DjEmYV.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': True,
#     'name': 'Prodej bytu 3+kk 67\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.041739182530414, 'lon': 14.556966817469586},
#     'has_matterport_url': False},
#    {'labelsReleased': [['panel'], []],
#     'has_panorama': 0,
#     'labels': ['Panelová'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'panel', 'elevator'],
#      ['small_shop',
#       'candy_shop',
#       'theater',
#       'tavern',
#       'movies',
#       'vet',
#       'playground',
#       'natural_attraction',
#       'atm',
#       'kindergarten',
#       'train',
#       'restaurant',
#       'metro',
#       'tram',
#       'shop',
#       'sports',
#       'bus_public_transport',
#       'medic',
#       'post_office',
#       'school',
#       'drugstore']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-cerny-most-dolezalova'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1990661452',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1990661452',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'RE-MAX-Partner-Praha-Reporyje',
#       'id': 17196,
#       'name': 'RE/MAX Partner',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QN_3/rSiLCT.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 9 - Černý Most',
#     'has_video': False,
#     'advert_images_count': 13,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1990661452,
#     'attractive_offer': 0,
#     'price': 4539000,
#     'price_czk': {'value_raw': 4539000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/qModdj.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/qModdj.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/0?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1990661452'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/qModdj.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_0/COuXnz.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_0/ChKDY1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_LN/PApe3m.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jr/I7mSCg.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_Ls/3QgrBm.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jw/qModdj.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 33\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.09224618253042, 'lon': 14.577589817469587},
#     'has_matterport_url': False}],
#   'is_saved': {'email_notification': False,
#    'notification_advert_count': 0,
#    'stack_id': 0,
#    'push_notification': False,
#    '_links': {'self': {'href': '/cs/v2/stacks'}},
#    'removed': False,
#    'saved': False},
#   'not_precise_location_count': {'result_size_auction': 0,
#    'result_size': 1146,
#    '_links': {'self': {'profile': '/estates/count/doc',
#      'href': '/cs/v2/estates/count?category_main_cb=1&locality_region_id=10&category_type_cb=3',
#      'title': 'Estate count'}}}},
#  'filterLabels': [],
#  'title': 'Byty na prodej Praha',
#  'filter': {'category_main_cb': '1',
#   'suggested_districtId': -1,
#   'locality_region_id': '10',
#   'category_type_cb': '1',
#   'suggested_regionId': -1},
#  '_links': {'self': {'href': '/cs/v2/estates?category_main_cb=1&locality_region_id=10&category_type_cb=1&page=0'},
#   'clusters_with_bounding_box_of_first_10': {'href': '/cs/v2/clusters?category_main_cb=1&locality_region_id=10&category_type_cb=1&per_page60=&leftBottomBounding=14.3106208175|50.0367651825&page=0&rightTopBounding=14.4883248175|50.1192731825'},
#   'rss': {'href': '/api/cs/v2/estates/rss?category_main_cb=1&category_type_cb=1&locality_region_id=10&suggested_regionId=-1&suggested_districtId=-1'}},
#  'locality': 'okres Praha 5',
#  'locality_dativ': 'na Praze 5',
#  'logged_in': False,
#  'per_page': 20,
#  'category_instrumental': 'výběrem či prodejem bytu',
#  'page': 0,
#  'filterLabels2': {'something_more3_3310': 'elevator',
#   'something_more1_3120': 'cellar',
#   'something_more1_3100': 'loggia',
#   'furnished_1': 'furnished',
#   'furnished_2': 'partly_furnished',
#   'furnished_3': 'not_furnished',
#   'building_condition_9': 'after_reconstruction',
#   'something_more2_3150': 'garage',
#   'something_more2_3130': 'basin',
#   'ownership_1': 'personal',
#   'ownership_3': 'state',
#   'ownership_2': 'collective',
#   'something_more3_1820': 'easy_access',
#   'energy_efficiency_rating_search_7': 'energy_rating_g',
#   'energy_efficiency_rating_search_6': 'energy_rating_f',
#   'energy_efficiency_rating_search_5': 'energy_rating_e',
#   'energy_efficiency_rating_search_4': 'energy_rating_d',
#   'energy_efficiency_rating_search_3': 'energy_rating_c',
#   'energy_efficiency_rating_search_2': 'energy_rating_b',
#   'energy_efficiency_rating_search_1': 'energy_rating_a',
#   'something_more1_3110': 'terrace',
#   'building_condition_6': 'new_building',
#   'something_more1_3090': 'balcony',
#   'building_condition_4': 'in_construction',
#   'building_type_search_3': 'other_sigular',
#   'something_more2_3120': 'cellar',
#   'building_type_search_1': 'panel',
#   'something_more2_3140': 'parking_lots',
#   'something_more1_200222': 'garden',
#   'building_type_search_2': 'brick'}}

# %% [markdown]
# ### 1b. Create a function converting sreality json data into pandas dataframe

# %%
len(d['_embedded']['estates'])
# Out:
# 21

# %%
len(d['_embedded']['estates'][4].keys())
# Out:
# 27

# %%
data_lists = [{'a':44, 'b':443},{'a':14, 'b':4454},{'a':45554, 'b':55553}]
pd.DataFrame(data_lists)
# Out:
#        a      b
# 0     44    443
# 1     14   4454
# 2  45554  55553

# %%
def convert_sreality_data_to_df(sreality_data):
    return pd.DataFrame(sreality_data['_embedded']['estates'])

raw = convert_sreality_data_to_df(d)

# %%
raw.head()
# Out:
#                                labelsReleased  has_panorama  \
# 0  [[new_building, parking_lots, garage], []]             0
# 1      [[parking_lots], [post_office, medic]]             0
# 2                                    [[], []]             0
# 3                           [[panel], [shop]]             0
# 4                   [[new_building], [metro]]             0
#
#                                               labels  is_auction  \
# 0                     [Novostavba, Parkování, Garáž]       False
# 1  [Parkování, Pošta 6 min. pěšky, Lékař 11 min. ...       False
# 2                                                 []       False
# 3                    [Panelová, Obchod 7 min. pěšky]       False
# 4                   [Novostavba, Metro 7 min. pěšky]       False
#
#                                            labelsAll  \
# 0  [[new_building, personal, balcony, cellar, ele...
# 1  [[personal, balcony, brick, parking_lots, furn...
# 2  [[personal, brick, cellar], [theater, vet, can...
# 3  [[personal, panel, cellar, elevator], [vet, sm...
# 4  [[new_building, personal, balcony, brick, elev...
#
#                                                  seo  exclusively_at_rk  \
# 0  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 1  {'category_main_cb': 1, 'category_sub_cb': 5, ...                  1
# 2  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  1
# 3  {'category_main_cb': 1, 'category_sub_cb': 7, ...                  0
# 4  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  1
#
#    category  has_floor_plan  \
# 0         1               1
# 1         1               1
# 2         1               0
# 3         1               0
# 4         1               1
#
#                                            _embedded  ...     hash_id  \
# 0  {'favourite': {'is_favourite': False, '_links'...  ...    91751756
# 1  {'favourite': {'is_favourite': False, '_links'...  ...  1756878156
# 2  {'favourite': {'is_favourite': False, '_links'...  ...  3097630028
# 3  {'favourite': {'is_favourite': False, '_links'...  ...   506537292
# 4  {'favourite': {'is_favourite': False, '_links'...  ...   598561868
#
#   attractive_offer     price  \
# 0                0  10047000
# 1                0  10823000
# 2                0   9317000
# 3                0   8537000
# 4                0   5406000
#
#                                            price_czk  \
# 0  {'value_raw': 10047000, 'unit': '', 'name': 'C...
# 1  {'value_raw': 10823000, 'unit': '', 'name': 'C...
# 2  {'value_raw': 9317000, 'unit': '', 'name': 'Ce...
# 3  {'value_raw': 8537000, 'unit': '', 'name': 'Ce...
# 4  {'value_raw': 5406000, 'unit': '', 'name': 'Ce...
#
#                                               _links    rus  \
# 0  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                      name  region_tip  \
# 0  Prodej bytu 2+kk 81 m²     2826899
# 1   Prodej bytu 2+1 92 m²           0
# 2  Prodej bytu 3+kk 67 m²           0
# 3   Prodej bytu 3+1 79 m²           0
# 4  Prodej bytu 1+kk 34 m²           0
#
#                                                  gps  has_matterport_url
# 0  {'lat': 50.07365718253041, 'lon': 14.456714817...               False
# 1  {'lat': 50.055205182530415, 'lon': 14.40737481...                True
# 2  {'lat': 50.05478218253042, 'lon': 14.400988817...               False
# 3  {'lat': 50.11638918253041, 'lon': 14.488324817...               False
# 4  {'lat': 50.03676518253042, 'lon': 14.310620817...               False
#
# [5 rows x 27 columns]

# %% [markdown]
# ### 1c. link function `1b` into function `1a`

# %%
def request_sreality(page, category_main_str, category_type_str, locality_region_id=10):
    category_mains = {'flat':1, 'house':2, 'land':3 }
    category_types = {'sell':1,'rent':2}
    template_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb={category_main}&category_type_cb={category_type}&locality_region_id={locality_region_id}&per_page60&page={page}'
    
    request_url = template_url.format(
        category_main=category_mains[category_main_str],
        category_type=category_types[category_type_str],
        locality_region_id=locality_region_id,
        page=page
    )
    
    try: 
        r = requests.get(request_url)
        return convert_sreality_data_to_df(r.json())
    except Exception as e:
        print(f'error requesting url {request_url}. Reason: {e.message}')
    
df = request_sreality(0, 'flat', 'sell', 10)
df.head()
# Out:
#                                labelsReleased  has_panorama  \
# 0  [[loggia, cellar, parking_lots], [school]]             0
# 1       [[furnished], [bus_public_transport]]             0
# 2                             [[balcony], []]             0
# 3                                    [[], []]             0
# 4                              [[loggia], []]             0
#
#                                            labels  is_auction  \
# 0  [Lodžie, Sklep, Parkování, Škola 1 min. pěšky]       False
# 1                    [Vybavený, Bus 4 min. pěšky]       False
# 2                                        [Balkon]       False
# 3                                              []       False
# 4                                        [Lodžie]       False
#
#                                            labelsAll  \
# 0  [[personal, loggia, cellar, parking_lots, part...
# 1  [[new_building, personal, brick, elevator, fur...
# 2  [[personal, balcony, elevator, garage, not_fur...
# 3  [[personal, elevator, garage, not_furnished], []]
# 4  [[personal, loggia, elevator, garage, not_furn...
#
#                                                  seo  exclusively_at_rk  \
# 0  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  1
# 1  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  1
# 2  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 3  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  0
# 4  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
#
#    category  has_floor_plan  \
# 0         1               0
# 1         1               0
# 2         1               1
# 3         1               1
# 4         1               1
#
#                                            _embedded  ...     hash_id  \
# 0  {'favourite': {'is_favourite': False, '_links'...  ...  1815491916
# 1  {'favourite': {'is_favourite': False, '_links'...  ...  2420491596
# 2  {'favourite': {'is_favourite': False, '_links'...  ...  4054193484
# 3  {'favourite': {'is_favourite': False, '_links'...  ...  2544244044
# 4  {'favourite': {'is_favourite': False, '_links'...  ...  2882934092
#
#   attractive_offer     price  \
# 0                0   4316000
# 1                0   8006000
# 2                0   9632000
# 3                0   6165000
# 4                0  11907000
#
#                                            price_czk  \
# 0  {'value_raw': 4316000, 'unit': '', 'name': 'Ce...
# 1  {'value_raw': 8006000, 'unit': '', 'name': 'Ce...
# 2  {'value_raw': 9632000, 'unit': '', 'name': 'Ce...
# 3  {'value_raw': 6165000, 'unit': '', 'name': 'Ce...
# 4  {'value_raw': 11907000, 'unit': '', 'name': 'C...
#
#                                               _links    rus  \
# 0  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                      name  region_tip  \
# 0  Prodej bytu 1+kk 29 m²           0
# 1  Prodej bytu 1+kk 69 m²           0
# 2  Prodej bytu 2+kk 50 m²           0
# 3  Prodej bytu 1+kk 30 m²           0
# 4  Prodej bytu 3+kk 72 m²           0
#
#                                                  gps  has_matterport_url
# 0  {'lat': 50.038989182530415, 'lon': 14.47748981...               False
# 1  {'lat': 50.08086718253041, 'lon': 14.309168817...               False
# 2  {'lat': 50.08985818253041, 'lon': 14.459570817...               False
# 3  {'lat': 50.08985818253041, 'lon': 14.459570817...               False
# 4  {'lat': 50.08985818253041, 'lon': 14.459570817...               False
#
# [5 rows x 27 columns]

# %% [markdown]
# ### 1c. Combining multiple requests into single df
#
# * Function should parametrize:
#     * `start_page` and `end_page`
#     * request parameters
# * construct a list of individual request dfs
# * then feed it into `pd.concat` function

# %%
raw.shape
# Out:
# (21, 27)

# %%
request_sreality
# Out:
# <function __main__.request_sreality(page, category_main_str, category_type_str, locality_region_id=10)>

# %%
def request_multiply_sreality(start_page, end_page, category_main_str, category_type_str, locality_region_id=10):
    pages = range(start_page, end_page + 1)
    list_of_dfs = [request_sreality(page, category_main_str, category_type_str, locality_region_id) for page in pages]
    return pd.concat(list_of_dfs)

df = request_multiply_sreality(1, 5, 'flat', 'sell',10)
df.shape
df.head()
# Out:
#                                       labelsReleased  has_panorama  \
# 0  [[balcony, cellar, parking_lots], [school, res...             0
# 1         [[loggia, cellar, parking_lots], [school]]             0
# 2              [[furnished], [bus_public_transport]]             0
# 3                                    [[balcony], []]             0
# 4                                           [[], []]             0
#
#                                               labels  is_auction  \
# 0  [Balkon, Sklep, Parkování, Škola 2 min. pěšky,...       False
# 1     [Lodžie, Sklep, Parkování, Škola 1 min. pěšky]       False
# 2                       [Vybavený, Bus 4 min. pěšky]       False
# 3                                           [Balkon]       False
# 4                                                 []       False
#
#                                            labelsAll  \
# 0  [[new_building, personal, balcony, cellar, ele...
# 1  [[personal, loggia, cellar, parking_lots, part...
# 2  [[new_building, personal, brick, elevator, fur...
# 3  [[personal, balcony, elevator, garage, not_fur...
# 4  [[personal, elevator, garage, not_furnished], []]
#
#                                                  seo  exclusively_at_rk  \
# 0  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  1
# 1  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  1
# 2  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  1
# 3  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 4  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  0
#
#    category  has_floor_plan  \
# 0         1               1
# 1         1               0
# 2         1               0
# 3         1               1
# 4         1               1
#
#                                            _embedded  ...     hash_id  \
# 0  {'favourite': {'is_favourite': False, '_links'...  ...  1433929036
# 1  {'favourite': {'is_favourite': False, '_links'...  ...  1815491916
# 2  {'favourite': {'is_favourite': False, '_links'...  ...  2420491596
# 3  {'favourite': {'is_favourite': False, '_links'...  ...  4054193484
# 4  {'favourite': {'is_favourite': False, '_links'...  ...  2544244044
#
#   attractive_offer    price  \
# 0                0  7623000
# 1                0  4316000
# 2                0  8006000
# 3                0  9632000
# 4                0  6165000
#
#                                            price_czk  \
# 0  {'value_raw': 7623000, 'unit': '', 'name': 'Ce...
# 1  {'value_raw': 4316000, 'unit': '', 'name': 'Ce...
# 2  {'value_raw': 8006000, 'unit': '', 'name': 'Ce...
# 3  {'value_raw': 9632000, 'unit': '', 'name': 'Ce...
# 4  {'value_raw': 6165000, 'unit': '', 'name': 'Ce...
#
#                                               _links    rus  \
# 0  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                      name  region_tip  \
# 0  Prodej bytu 1+kk 46 m²     2826899
# 1  Prodej bytu 1+kk 29 m²           0
# 2  Prodej bytu 1+kk 69 m²           0
# 3  Prodej bytu 2+kk 50 m²           0
# 4  Prodej bytu 1+kk 30 m²           0
#
#                                                  gps  has_matterport_url
# 0  {'lat': 50.073214182530414, 'lon': 14.45730481...               False
# 1  {'lat': 50.038989182530415, 'lon': 14.47748981...               False
# 2  {'lat': 50.08086718253041, 'lon': 14.309168817...               False
# 3  {'lat': 50.08985818253041, 'lon': 14.459570817...               False
# 4  {'lat': 50.08985818253041, 'lon': 14.459570817...               False
#
# [5 rows x 27 columns]

# %%
df = df.reset_index().drop('index', axis=1)
df
# Out:
#                                         labelsReleased  has_panorama  \
# 0    [[balcony, cellar, parking_lots], [school, res...             0
# 1           [[loggia, cellar, parking_lots], [school]]             0
# 2                [[furnished], [bus_public_transport]]             0
# 3                                      [[balcony], []]             0
# 4                                             [[], []]             0
# ..                                                 ...           ...
# 100                                           [[], []]             0
# 101                     [[terrace, not_furnished], []]             0
# 102                                           [[], []]             0
# 103                              [[not_furnished], []]             0
# 104                              [[not_furnished], []]             0
#
#                                                 labels  is_auction  \
# 0    [Balkon, Sklep, Parkování, Škola 2 min. pěšky,...       False
# 1       [Lodžie, Sklep, Parkování, Škola 1 min. pěšky]       False
# 2                         [Vybavený, Bus 4 min. pěšky]       False
# 3                                             [Balkon]       False
# 4                                                   []       False
# ..                                                 ...         ...
# 100                                                 []       False
# 101                               [Terasa, Nevybavený]       False
# 102                                                 []       False
# 103                                       [Nevybavený]       False
# 104                                       [Nevybavený]       False
#
#                                              labelsAll  \
# 0    [[new_building, personal, balcony, cellar, ele...
# 1    [[personal, loggia, cellar, parking_lots, part...
# 2    [[new_building, personal, brick, elevator, fur...
# 3    [[personal, balcony, elevator, garage, not_fur...
# 4    [[personal, elevator, garage, not_furnished], []]
# ..                                                 ...
# 100  [[personal, after_reconstruction, brick], [sma...
# 101  [[personal, terrace, brick, cellar, not_furnis...
# 102  [[personal, after_reconstruction, brick, cella...
# 103  [[personal, after_reconstruction, brick, cella...
# 104  [[personal, after_reconstruction, brick, cella...
#
#                                                    seo  exclusively_at_rk  \
# 0    {'category_main_cb': 1, 'category_sub_cb': 2, ...                  1
# 1    {'category_main_cb': 1, 'category_sub_cb': 2, ...                  1
# 2    {'category_main_cb': 1, 'category_sub_cb': 2, ...                  1
# 3    {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 4    {'category_main_cb': 1, 'category_sub_cb': 2, ...                  0
# ..                                                 ...                ...
# 100  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 101  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  0
# 102  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  0
# 103  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 104  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
#
#      category  has_floor_plan  \
# 0           1               1
# 1           1               0
# 2           1               0
# 3           1               1
# 4           1               1
# ..        ...             ...
# 100         1               1
# 101         1               1
# 102         1               1
# 103         1               0
# 104         1               1
#
#                                              _embedded  ...     hash_id  \
# 0    {'favourite': {'is_favourite': False, '_links'...  ...  1433929036
# 1    {'favourite': {'is_favourite': False, '_links'...  ...  1815491916
# 2    {'favourite': {'is_favourite': False, '_links'...  ...  2420491596
# 3    {'favourite': {'is_favourite': False, '_links'...  ...  4054193484
# 4    {'favourite': {'is_favourite': False, '_links'...  ...  2544244044
# ..                                                 ...  ...         ...
# 100  {'favourite': {'is_favourite': False, '_links'...  ...   643286348
# 101  {'favourite': {'is_favourite': False, '_links'...  ...  1421329740
# 102  {'favourite': {'is_favourite': False, '_links'...  ...  2594686284
# 103  {'favourite': {'is_favourite': False, '_links'...  ...  2644981068
# 104  {'favourite': {'is_favourite': False, '_links'...  ...  2964796748
#
#     attractive_offer    price  \
# 0                  0  7623000
# 1                  0  4316000
# 2                  0  8006000
# 3                  0  9632000
# 4                  0  6165000
# ..               ...      ...
# 100                0  7308000
# 101                0  6074000
# 102                0  7601000
# 103                0  6890000
# 104                0  7101000
#
#                                              price_czk  \
# 0    {'value_raw': 7623000, 'unit': '', 'name': 'Ce...
# 1    {'value_raw': 4316000, 'unit': '', 'name': 'Ce...
# 2    {'value_raw': 8006000, 'unit': '', 'name': 'Ce...
# 3    {'value_raw': 9632000, 'unit': '', 'name': 'Ce...
# 4    {'value_raw': 6165000, 'unit': '', 'name': 'Ce...
# ..                                                 ...
# 100  {'value_raw': 7308000, 'unit': '', 'name': 'Ce...
# 101  {'value_raw': 6074000, 'unit': '', 'name': 'Ce...
# 102  {'value_raw': 7601000, 'unit': '', 'name': 'Ce...
# 103  {'alt': {'value_raw': 130000, 'unit': 'za m²'}...
# 104  {'value_raw': 7101000, 'unit': '', 'name': 'Ce...
#
#                                                 _links    rus  \
# 0    {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1    {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2    {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3    {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4    {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# ..                                                 ...    ...
# 100  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 101  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 102  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 103  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 104  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                        name  region_tip  \
# 0    Prodej bytu 1+kk 46 m²     2826899
# 1    Prodej bytu 1+kk 29 m²           0
# 2    Prodej bytu 1+kk 69 m²           0
# 3    Prodej bytu 2+kk 50 m²           0
# 4    Prodej bytu 1+kk 30 m²           0
# ..                      ...         ...
# 100  Prodej bytu 2+kk 58 m²           0
# 101  Prodej bytu 1+kk 50 m²           0
# 102  Prodej bytu 1+kk 58 m²           0
# 103  Prodej bytu 2+kk 57 m²           0
# 104  Prodej bytu 2+kk 59 m²           0
#
#                                                    gps  has_matterport_url
# 0    {'lat': 50.073214182530414, 'lon': 14.45730481...               False
# 1    {'lat': 50.038989182530415, 'lon': 14.47748981...               False
# 2    {'lat': 50.08086718253041, 'lon': 14.309168817...               False
# 3    {'lat': 50.08985818253041, 'lon': 14.459570817...               False
# 4    {'lat': 50.08985818253041, 'lon': 14.459570817...               False
# ..                                                 ...                 ...
# 100  {'lat': 50.08401418253042, 'lon': 14.359065817...               False
# 101  {'lat': 50.08401418253042, 'lon': 14.359065817...               False
# 102  {'lat': 50.08401418253042, 'lon': 14.359065817...               False
# 103  {'lat': 50.08401418253042, 'lon': 14.359065817...               False
# 104  {'lat': 50.08401418253042, 'lon': 14.359065817...               False
#
# [105 rows x 27 columns]

# %% [markdown]
# ## Task 2: Cleaning data
#
# ### 2a. Filter columns
# * filter only columns: `['locality', 'price', 'name', 'gps','hash_id','exclusively_at_rk']`
# * use `.copy()` to avoid `SettingWithCopyWarning` later

# %%
clean = df[['locality', 'price', 'name', 'gps','hash_id','exclusively_at_rk']].copy()
clean
# Out:
#                  locality    price                    name  \
# 0        Praha 3 - Žižkov  7623000  Prodej bytu 1+kk 46 m²
# 1        Praha 4 - Michle  4316000  Prodej bytu 1+kk 29 m²
# 2        Praha 6 - Ruzyně  8006000  Prodej bytu 1+kk 69 m²
# 3    Praha 7 - Holešovice  9632000  Prodej bytu 2+kk 50 m²
# 4    Praha 7 - Holešovice  6165000  Prodej bytu 1+kk 30 m²
# ..                    ...      ...                     ...
# 100  Praha 6 - Veleslavín  7308000  Prodej bytu 2+kk 58 m²
# 101  Praha 6 - Veleslavín  6074000  Prodej bytu 1+kk 50 m²
# 102  Praha 6 - Veleslavín  7601000  Prodej bytu 1+kk 58 m²
# 103  Praha 6 - Veleslavín  6890000  Prodej bytu 2+kk 57 m²
# 104  Praha 6 - Veleslavín  7101000  Prodej bytu 2+kk 59 m²
#
#                                                    gps     hash_id  \
# 0    {'lat': 50.073214182530414, 'lon': 14.45730481...  1433929036
# 1    {'lat': 50.038989182530415, 'lon': 14.47748981...  1815491916
# 2    {'lat': 50.08086718253041, 'lon': 14.309168817...  2420491596
# 3    {'lat': 50.08985818253041, 'lon': 14.459570817...  4054193484
# 4    {'lat': 50.08985818253041, 'lon': 14.459570817...  2544244044
# ..                                                 ...         ...
# 100  {'lat': 50.08401418253042, 'lon': 14.359065817...   643286348
# 101  {'lat': 50.08401418253042, 'lon': 14.359065817...  1421329740
# 102  {'lat': 50.08401418253042, 'lon': 14.359065817...  2594686284
# 103  {'lat': 50.08401418253042, 'lon': 14.359065817...  2644981068
# 104  {'lat': 50.08401418253042, 'lon': 14.359065817...  2964796748
#
#      exclusively_at_rk
# 0                    1
# 1                    1
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 100                  0
# 101                  0
# 102                  0
# 103                  0
# 104                  0
#
# [105 rows x 6 columns]

# %% [markdown]
# ### 2b: GPS
# * Convert dictionary in `gps` column into two columns - `lat` and `lon`
# * use apply function on gps column
# * Note apply can return multiple columns

# %%
clean[['lat', 'lon']] = clean.gps.apply(lambda x: pd.Series({'lat': x['lat'], 'lon': x['lon']}))

# %%
clean
# Out:
#                  locality    price                    name  \
# 0        Praha 3 - Žižkov  7623000  Prodej bytu 1+kk 46 m²
# 1        Praha 4 - Michle  4316000  Prodej bytu 1+kk 29 m²
# 2        Praha 6 - Ruzyně  8006000  Prodej bytu 1+kk 69 m²
# 3    Praha 7 - Holešovice  9632000  Prodej bytu 2+kk 50 m²
# 4    Praha 7 - Holešovice  6165000  Prodej bytu 1+kk 30 m²
# ..                    ...      ...                     ...
# 100  Praha 6 - Veleslavín  7308000  Prodej bytu 2+kk 58 m²
# 101  Praha 6 - Veleslavín  6074000  Prodej bytu 1+kk 50 m²
# 102  Praha 6 - Veleslavín  7601000  Prodej bytu 1+kk 58 m²
# 103  Praha 6 - Veleslavín  6890000  Prodej bytu 2+kk 57 m²
# 104  Praha 6 - Veleslavín  7101000  Prodej bytu 2+kk 59 m²
#
#                                                    gps     hash_id  \
# 0    {'lat': 50.073214182530414, 'lon': 14.45730481...  1433929036
# 1    {'lat': 50.038989182530415, 'lon': 14.47748981...  1815491916
# 2    {'lat': 50.08086718253041, 'lon': 14.309168817...  2420491596
# 3    {'lat': 50.08985818253041, 'lon': 14.459570817...  4054193484
# 4    {'lat': 50.08985818253041, 'lon': 14.459570817...  2544244044
# ..                                                 ...         ...
# 100  {'lat': 50.08401418253042, 'lon': 14.359065817...   643286348
# 101  {'lat': 50.08401418253042, 'lon': 14.359065817...  1421329740
# 102  {'lat': 50.08401418253042, 'lon': 14.359065817...  2594686284
# 103  {'lat': 50.08401418253042, 'lon': 14.359065817...  2644981068
# 104  {'lat': 50.08401418253042, 'lon': 14.359065817...  2964796748
#
#      exclusively_at_rk        lat        lon
# 0                    1  50.073214  14.457305
# 1                    1  50.038989  14.477490
# 2                    1  50.080867  14.309169
# 3                    0  50.089858  14.459571
# 4                    0  50.089858  14.459571
# ..                 ...        ...        ...
# 100                  0  50.084014  14.359066
# 101                  0  50.084014  14.359066
# 102                  0  50.084014  14.359066
# 103                  0  50.084014  14.359066
# 104                  0  50.084014  14.359066
#
# [105 rows x 8 columns]

# %% [markdown]
# ### 2b. Get flat type from name
# * Name is always represented by string `Prodej bytu [type of flat] [Area] m^2`
# * try picking third word in string
# * check meaningfulness using `.value_counts()`

# %%
clean['flat_type'] = clean.name.apply(lambda nm:nm.split()[2])

# %% [markdown]
# ### 2c. Get area from name
# * Naive: select the word before last word
# * Then try navigating using the index of `'m²'`
# * if this also fail, then you will need to use regex

# %%
clean['area_1'] = clean.name.apply(lambda nm:nm.split()[3])

# %%
n = 'Prodej bytu 4+kk 128 m²'
splited = n.split()
print(splited)
splited.index('m²')
# Out:
# ['Prodej', 'bytu', '4+kk', '128', 'm²']
# 4

# %%
int(splited[3])
# Out:
# 128

# %%
def name_to_area(nm):
    splitted= nm.split()
    m2_idx = splitted.index('m²')
    return int(splitted[m2_idx-1])

clean['area_2'] = clean.name.apply(name_to_area)
clean
# Out:
#                  locality    price                    name  \
# 0        Praha 3 - Žižkov  7623000  Prodej bytu 1+kk 46 m²
# 1        Praha 4 - Michle  4316000  Prodej bytu 1+kk 29 m²
# 2        Praha 6 - Ruzyně  8006000  Prodej bytu 1+kk 69 m²
# 3    Praha 7 - Holešovice  9632000  Prodej bytu 2+kk 50 m²
# 4    Praha 7 - Holešovice  6165000  Prodej bytu 1+kk 30 m²
# ..                    ...      ...                     ...
# 100  Praha 6 - Veleslavín  7308000  Prodej bytu 2+kk 58 m²
# 101  Praha 6 - Veleslavín  6074000  Prodej bytu 1+kk 50 m²
# 102  Praha 6 - Veleslavín  7601000  Prodej bytu 1+kk 58 m²
# 103  Praha 6 - Veleslavín  6890000  Prodej bytu 2+kk 57 m²
# 104  Praha 6 - Veleslavín  7101000  Prodej bytu 2+kk 59 m²
#
#                                                    gps     hash_id  \
# 0    {'lat': 50.073214182530414, 'lon': 14.45730481...  1433929036
# 1    {'lat': 50.038989182530415, 'lon': 14.47748981...  1815491916
# 2    {'lat': 50.08086718253041, 'lon': 14.309168817...  2420491596
# 3    {'lat': 50.08985818253041, 'lon': 14.459570817...  4054193484
# 4    {'lat': 50.08985818253041, 'lon': 14.459570817...  2544244044
# ..                                                 ...         ...
# 100  {'lat': 50.08401418253042, 'lon': 14.359065817...   643286348
# 101  {'lat': 50.08401418253042, 'lon': 14.359065817...  1421329740
# 102  {'lat': 50.08401418253042, 'lon': 14.359065817...  2594686284
# 103  {'lat': 50.08401418253042, 'lon': 14.359065817...  2644981068
# 104  {'lat': 50.08401418253042, 'lon': 14.359065817...  2964796748
#
#      exclusively_at_rk        lat        lon flat_type area_1  area_2
# 0                    1  50.073214  14.457305      1+kk     46      46
# 1                    1  50.038989  14.477490      1+kk     29      29
# 2                    1  50.080867  14.309169      1+kk     69      69
# 3                    0  50.089858  14.459571      2+kk     50      50
# 4                    0  50.089858  14.459571      1+kk     30      30
# ..                 ...        ...        ...       ...    ...     ...
# 100                  0  50.084014  14.359066      2+kk     58      58
# 101                  0  50.084014  14.359066      1+kk     50      50
# 102                  0  50.084014  14.359066      1+kk     58      58
# 103                  0  50.084014  14.359066      2+kk     57      57
# 104                  0  50.084014  14.359066      2+kk     59      59
#
# [105 rows x 11 columns]

# %%
clean[clean['area_1']==clean['area_2']]
# Out:
# Empty DataFrame
# Columns: [locality, price, name, gps, hash_id, exclusively_at_rk, lat, lon, flat_type, area_1, area_2]
# Index: []

# %%
clean[clean['area_1'].astype(int)==clean['area_2']]
# Out:
#                  locality    price                    name  \
# 0        Praha 3 - Žižkov  7623000  Prodej bytu 1+kk 46 m²
# 1        Praha 4 - Michle  4316000  Prodej bytu 1+kk 29 m²
# 2        Praha 6 - Ruzyně  8006000  Prodej bytu 1+kk 69 m²
# 3    Praha 7 - Holešovice  9632000  Prodej bytu 2+kk 50 m²
# 4    Praha 7 - Holešovice  6165000  Prodej bytu 1+kk 30 m²
# ..                    ...      ...                     ...
# 100  Praha 6 - Veleslavín  7308000  Prodej bytu 2+kk 58 m²
# 101  Praha 6 - Veleslavín  6074000  Prodej bytu 1+kk 50 m²
# 102  Praha 6 - Veleslavín  7601000  Prodej bytu 1+kk 58 m²
# 103  Praha 6 - Veleslavín  6890000  Prodej bytu 2+kk 57 m²
# 104  Praha 6 - Veleslavín  7101000  Prodej bytu 2+kk 59 m²
#
#                                                    gps     hash_id  \
# 0    {'lat': 50.073214182530414, 'lon': 14.45730481...  1433929036
# 1    {'lat': 50.038989182530415, 'lon': 14.47748981...  1815491916
# 2    {'lat': 50.08086718253041, 'lon': 14.309168817...  2420491596
# 3    {'lat': 50.08985818253041, 'lon': 14.459570817...  4054193484
# 4    {'lat': 50.08985818253041, 'lon': 14.459570817...  2544244044
# ..                                                 ...         ...
# 100  {'lat': 50.08401418253042, 'lon': 14.359065817...   643286348
# 101  {'lat': 50.08401418253042, 'lon': 14.359065817...  1421329740
# 102  {'lat': 50.08401418253042, 'lon': 14.359065817...  2594686284
# 103  {'lat': 50.08401418253042, 'lon': 14.359065817...  2644981068
# 104  {'lat': 50.08401418253042, 'lon': 14.359065817...  2964796748
#
#      exclusively_at_rk        lat        lon flat_type area_1  area_2
# 0                    1  50.073214  14.457305      1+kk     46      46
# 1                    1  50.038989  14.477490      1+kk     29      29
# 2                    1  50.080867  14.309169      1+kk     69      69
# 3                    0  50.089858  14.459571      2+kk     50      50
# 4                    0  50.089858  14.459571      1+kk     30      30
# ..                 ...        ...        ...       ...    ...     ...
# 100                  0  50.084014  14.359066      2+kk     58      58
# 101                  0  50.084014  14.359066      1+kk     50      50
# 102                  0  50.084014  14.359066      1+kk     58      58
# 103                  0  50.084014  14.359066      2+kk     57      57
# 104                  0  50.084014  14.359066      2+kk     59      59
#
# [105 rows x 11 columns]

# %% [markdown]
# ## Bonus: Convert `labelsAll` into categorical variables
#
# ### Task 4a. Get all possible label names
# * deal with nested-list structure
# * Hint: try to sum the whole column
# * Needed to Iterate through all labels in all rows and

# %%
['d'] + ['c']
# Out:
# ['d', 'c']

# %%
possible_labels = list(set([i for sublist in raw.labelsAll.sum() for i in sublist]))
possible_labels
# Out:
# ['garage',
#  'post_office',
#  'collective',
#  'natural_attraction',
#  'tram',
#  'playground',
#  'movies',
#  'terrace',
#  'school',
#  'atm',
#  'sports',
#  'furnished',
#  'after_reconstruction',
#  'not_furnished',
#  'drugstore',
#  'kindergarten',
#  'new_building',
#  'cellar',
#  'shop',
#  'bus_public_transport',
#  'partly_furnished',
#  'balcony',
#  'vet',
#  'metro',
#  'train',
#  'brick',
#  'panel',
#  'candy_shop',
#  'elevator',
#  'small_shop',
#  'restaurant',
#  'personal',
#  'tavern',
#  'sightseeing',
#  'medic',
#  'theater',
#  'parking_lots']

# %% [markdown]
# ### 4b. Test existence of label `cellar` for offers
# * again deal with nested list of list structure
# * write generic function `test_existence_of_label(offer_labels,label)`

# %%
def test_existence_of_label(offer_labels,label):
    return 'cellar' in [item for sublist in offer_labels for item in sublist]

raw.labelsAll.apply(lambda offer_labels: test_existence_of_label(offer_labels, 'cellar'))
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11     True
# 12     True
# 13    False
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# Name: labelsAll, dtype: bool

# %% [markdown]
# ### 4c. Test existence of all possible labels
# * use apply returning series with all labels

# %%
def existence_of_all_labels(offer_labels, possible_labels):
    return pd.Series({
        label:test_existence_of_label(offer_labels,label)
        for label in possible_labels
    })

raw.labelsAll.apply(lambda offer_labels: existence_of_all_labels(offer_labels, possible_labels))
# Out:
#     garage  post_office  collective  natural_attraction   tram  playground  \
# 0     True         True        True                True   True        True
# 1    False        False       False               False  False       False
# 2     True         True        True                True   True        True
# 3     True         True        True                True   True        True
# 4    False        False       False               False  False       False
# 5     True         True        True                True   True        True
# 6     True         True        True                True   True        True
# 7     True         True        True                True   True        True
# 8     True         True        True                True   True        True
# 9     True         True        True                True   True        True
# 10   False        False       False               False  False       False
# 11    True         True        True                True   True        True
# 12    True         True        True                True   True        True
# 13   False        False       False               False  False       False
# 14    True         True        True                True   True        True
# 15    True         True        True                True   True        True
# 16   False        False       False               False  False       False
# 17   False        False       False               False  False       False
# 18   False        False       False               False  False       False
# 19    True         True        True                True   True        True
# 20   False        False       False               False  False       False
#
#     movies  terrace  school    atm  ...  candy_shop  elevator  small_shop  \
# 0     True     True    True   True  ...        True      True        True
# 1    False    False   False  False  ...       False     False       False
# 2     True     True    True   True  ...        True      True        True
# 3     True     True    True   True  ...        True      True        True
# 4    False    False   False  False  ...       False     False       False
# 5     True     True    True   True  ...        True      True        True
# 6     True     True    True   True  ...        True      True        True
# 7     True     True    True   True  ...        True      True        True
# 8     True     True    True   True  ...        True      True        True
# 9     True     True    True   True  ...        True      True        True
# 10   False    False   False  False  ...       False     False       False
# 11    True     True    True   True  ...        True      True        True
# 12    True     True    True   True  ...        True      True        True
# 13   False    False   False  False  ...       False     False       False
# 14    True     True    True   True  ...        True      True        True
# 15    True     True    True   True  ...        True      True        True
# 16   False    False   False  False  ...       False     False       False
# 17   False    False   False  False  ...       False     False       False
# 18   False    False   False  False  ...       False     False       False
# 19    True     True    True   True  ...        True      True        True
# 20   False    False   False  False  ...       False     False       False
#
#     restaurant  personal  tavern  sightseeing  medic  theater  parking_lots
# 0         True      True    True         True   True     True          True
# 1        False     False   False        False  False    False         False
# 2         True      True    True         True   True     True          True
# 3         True      True    True         True   True     True          True
# 4        False     False   False        False  False    False         False
# 5         True      True    True         True   True     True          True
# 6         True      True    True         True   True     True          True
# 7         True      True    True         True   True     True          True
# 8         True      True    True         True   True     True          True
# 9         True      True    True         True   True     True          True
# 10       False     False   False        False  False    False         False
# 11        True      True    True         True   True     True          True
# 12        True      True    True         True   True     True          True
# 13       False     False   False        False  False    False         False
# 14        True      True    True         True   True     True          True
# 15        True      True    True         True   True     True          True
# 16       False     False   False        False  False    False         False
# 17       False     False   False        False  False    False         False
# 18       False     False   False        False  False    False         False
# 19        True      True    True         True   True     True          True
# 20       False     False   False        False  False    False         False
#
# [21 rows x 37 columns]
